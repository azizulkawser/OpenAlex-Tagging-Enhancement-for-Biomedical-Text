# %% [markdown]
# Load the golden dataset

# %%
import pandas as pd
# Specify the file path
file_path = ".\i2b2_2010_VA_training_data\consolidated_concpet_training_data\i2b2_annotated_concepts_2023AB.csv"

# Read the text file into a DataFrame
df_golden = pd.read_csv(file_path)

# %%
# change column names for convenience
df_golden = df_golden.rename(columns={
    'Concept List': 'Manually Annotated Concepts',
    'File Name': 'Full File Name',
    'File Name without Extension': 'File Name',
    'CUIs': 'i2b2_Annotated_CUIs',
    'TUIs': 'i2b2_Annotated_TUIs'
})

# %%
df_golden.head()
# Out:
#         Full File Name        File Name  \
# 0     018636330_DH.con     018636330_DH
# 1    026350193_RWH.con    026350193_RWH
# 2    037945397_RWH.con    037945397_RWH
# 3  044687343_ELMVH.con  044687343_ELMVH
# 4     060376519_DH.con     060376519_DH
#
#                                         File Content  \
# 0  c="a workup" 27:2 27:3||t="test"\nc="pain" 55:...
# 1  c="flexeril" 39:5 39:5||t="treatment"\nc="cons...
# 2  c="ivf" 39:0 39:0||t="treatment"\nc="near sync...
# 3  c="lisinopril pump" 88:5 88:6||t="treatment"\n...
# 4  c="dizziness" 31:0 31:0||t="problem"\nc="benig...
#
#                          Manually Annotated Concepts  \
# 0  ['a workup', 'pain', 'microscopic anterior cer...
# 1  ['flexeril', 'constipation', 'left shoulder / ...
# 2  ['ivf', 'near syncope', 'recurrent dizziness',...
# 3  ['lisinopril pump', 'bipap', 'copd', 'nad', 'f...
# 4  ['dizziness', 'benign positional vertigo', 'me...
#
#                                    Concept Type List  \
# 0  ['test', 'problem', 'treatment', 'problem', 't...
# 1  ['treatment', 'problem', 'problem', 'treatment...
# 2  ['treatment', 'problem', 'problem', 'problem',...
# 3  ['treatment', 'treatment', 'problem', 'problem...
# 4  ['problem', 'problem', 'treatment', 'problem',...
#
#                                  i2b2_Annotated_CUIs  \
# 0  ['C0020473', 'C0592278', 'C0015967', 'C0728797...
# 1  ['C0012306', 'C0728797', 'C0009214', 'C0262573...
# 2  ['C0015915', 'C2263086', 'C1419864', 'C4284399...
# 3  ['C5539771', 'C3539604', 'C1623258', 'C2051415...
# 4  ['C0155502', 'C0018681', 'C0012833', 'C0015967...
#
#                                  i2b2_Annotated_TUIs
# 0  ['T169', 'T121', 'T201', 'T168', 'T047', 'T033...
# 1           ['T121', 'T201', 'T037', 'T184', 'T109']
# 2  ['T026', 'T028', 'T201', 'T047', 'T184', 'T061...
# 3  ['T055', 'T025', 'T201', 'T078', 'T033', 'T184...
# 4  ['T169', 'T121', 'T201', 'T033', 'T047', 'T184...

# %% [markdown]
# Load OpenAlex, cTAKES and MetaMap created test dataset

# %%
import pandas as pd
# Specify the file path
OpenAlex_file_path = ".\i2b2_2010_VA_training_data\i2b2_text_reports_OpenAlex_processing\OpenAlex_output\i2b2_text_parsed_concepts_OA.csv"
cTAKES_file_path = ".\i2b2_2010_VA_training_data\i2b2_text_reports_cTAKES_processing\cTAKES_output\i2b2_text_parsed_concepts_cTAKES.csv"
MM_file_path = ".\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\MM_output\i2b2_text_parsed_concepts_MM.csv"

# Read the text file into a DataFrame
df_OpenAlex = pd.read_csv(OpenAlex_file_path)
df_cTAKES = pd.read_csv(cTAKES_file_path)
df_MM = pd.read_csv(MM_file_path)

# %%
df_OpenAlex['File Name'] = df_OpenAlex['File Name'].str.replace('.json', '')

# change column names for convenience
df_OpenAlex = df_OpenAlex.rename(columns={
    'Concepts': 'OpenAlex_Concepts',
    'Scores': 'OpenAlex_Scores',
    'CUIs': 'OA_CUIs',
    'TUIs': 'OA_TUIs'
})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2704\2718599961.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_OpenAlex['File Name'] = df_OpenAlex['File Name'].str.replace('.json', '')

# %%
df_OpenAlex.head()
# Out:
#          File Name                                  OpenAlex_Concepts  \
# 0     018636330_DH  ['medicine', 'clonus', 'hyperreflexia', 'physi...
# 1    026350193_RWH  ['medicine', 'nausea', 'constipation', 'codein...
# 2    037945397_RWH  ['medicine', 'chest pain', 'weakness', 'syncop...
# 3  044687343_ELMVH  ['fluticasone propionate', 'chemistry', 'medic...
# 4     060376519_DH  ['medicine', 'complaint', 'emergency departmen...
#
#                                      OpenAlex_Scores  \
# 0  [0.9112345576286316, 0.7156546115875244, 0.610...
# 1  [0.7432302832603455, 0.5929043889045715, 0.591...
# 2  [0.8295673727989197, 0.5714144706726074, 0.482...
# 3  [0.6071492433547974, 0.49507227540016174, 0.42...
# 4  [0.7121383547782898, 0.5547797679901123, 0.483...
#
#                                              OA_CUIs  \
# 0  ['C0013227', 'C0220870', 'C0038895', 'C0262926...
# 1  ['C0013227', 'C0002912', 'C0699718', 'C3864418...
# 2  ['C3714552', 'C0013227', 'C0587599', 'C0002912...
# 3  ['C0013227', 'C0002912', 'C0025118', 'C2219802...
# 4  ['C0013227', 'C0587599', 'C0022893', 'C1069915...
#
#                                              OA_TUIs
# 0  ['T169', 'T184', 'T058', 'T060', 'T091', 'T033...
# 1  ['T201', 'T184', 'T091', 'T033', 'T170', 'T121...
# 2  ['T201', 'T011', 'T184', 'T058', 'T091', 'T033...
# 3  ['T059', 'T169', 'T201', 'T090', 'T184', 'T033...
# 4  ['T093', 'T204', 'T201', 'T184', 'T058', 'T047...

# %%
# change column names for convenience
df_cTAKES = df_cTAKES.rename(columns={
    'File_name': 'File Name',
    'Tokens': 'cTAKES_Concepts',
    'CUIs': 'cTAKES_CUIs',
    'TUIs': 'cTAKES_TUIs'
})

# %%
df_cTAKES.head()
# Out:
#          File Name                                    cTAKES_Concepts  \
# 0     018636330_DH  ['DIS', 'Report Status', 'DIAGNOSIS', 'HISTORY...
# 1    026350193_RWH  ['DIS', 'Report Status', 'service', 'Discharge...
# 2    037945397_RWH  ['DIS', 'Report Status', 'Yes', 'Discharge Sta...
# 3  044687343_ELMVH  ['DIS', 'Report Status', 'Service', 'YES', 'Sh...
# 4     060376519_DH  ['DIS', 'Report Status', 'Discharge Status', '...
#
#                                          cTAKES_CUIs  \
# 0  ['C1444662', 'C0586177', 'C0011900', 'C0262926...
# 1  ['C1444662', 'C0586177', 'C0557854', 'C0586514...
# 2  ['C1444662', 'C0586177', 'C1298907', 'C0586514...
# 3  ['C1444662', 'C0586177', 'C0557854', 'C1298907...
# 4  ['C1444662', 'C0586177', 'C0586514', 'C0277786...
#
#                                          cTAKES_TUIs
# 0  ['T033', 'T033', 'T033', 'T033', 'T184', 'T033...
# 1  ['T033', 'T033', 'T057', 'T033', 'T033', 'T033...
# 2  ['T033', 'T033', 'T033', 'T033', 'T033', 'T184...
# 3  ['T033', 'T033', 'T057', 'T033', 'T184', 'T044...
# 4  ['T033', 'T033', 'T033', 'T033', 'T184', 'T184...

# %%
# change column names for convenience
df_MM = df_MM.rename(columns={
    'Preferred Names': 'MM_Concepts',
    'SemTypes': 'MM_SemTypes',
    'CUIs': 'MM_CUIs',
    'TUIs': 'MM_TUIs'
})

# Convert the comma-separated string into a list of codes for each row
df_MM['MM_CUIs'] = df_MM['MM_CUIs'].apply(lambda x: x.split(', '))

# %%
df_MM.head()
# Out:
#          File Name                                        MM_Concepts  \
# 0     018636330_DH  Oral, PO (eyeglasses), Doctor of Medicine, MG,...
# 1    026350193_RWH  Papillary craniopharyngioma, Pneumocystis jiro...
# 2    037945397_RWH  Patients, Papillary craniopharyngioma, Pneumoc...
# 3  044687343_ELMVH  Give - dosing instruction imperative, Then, Un...
# 4     060376519_DH  Papillary craniopharyngioma, Pneumocystis jiro...
#
#                                              MM_CUIs  \
# 0  [C0442027, C4759839, C1512018, C4321396, C0024...
# 1  [C0431128, C1535939, C3896095, C0030705, C3274...
# 2  [C0030705, C0431128, C1535939, C3896095, C1707...
# 3  [C1947971, C1883708, C0439148, C3814390, C4049...
# 4  [C0431128, C1535939, C3896095, C1512018, C0030...
#
#                                          MM_SemTypes  \
# 0  spco, fndg, inpr, diap, diap, qnco, popg, clas...
# 1  neop, dsyn, moft, podg, hlca, inpr, inpr, fndg...
# 2  podg, neop, dsyn, moft, bodm, popg, inpr, inpr...
# 3  ftcn, tmco, qnco, inpr, mamm, inpr, qnco, qnco...
# 4  neop, dsyn, moft, inpr, podg, clna, fndg, inpr...
#
#                                              MM_TUIs
# 0  ['T082', 'T033', 'T170', 'T060', 'T060', 'T081...
# 1  ['T191', 'T047', 'T044', 'T101', 'T058', 'T170...
# 2  ['T101', 'T191', 'T047', 'T044', 'T122', 'T098...
# 3  ['T169', 'T079', 'T081', 'T170', 'T015', 'T170...
# 4  ['T191', 'T047', 'T044', 'T170', 'T101', 'T201...

# %% [markdown]
# Create a merged dataset

# %%
# Merge the DataFrames on the "File Name" column
complete_dataset = pd.merge(df_golden, df_OpenAlex, on='File Name')
complete_dataset = pd.merge(complete_dataset, df_cTAKES, on='File Name')
complete_dataset = pd.merge(complete_dataset, df_MM, on='File Name')

# %%
complete_dataset.head()
# Out:
#         Full File Name        File Name  \
# 0     018636330_DH.con     018636330_DH
# 1    026350193_RWH.con    026350193_RWH
# 2    037945397_RWH.con    037945397_RWH
# 3  044687343_ELMVH.con  044687343_ELMVH
# 4     060376519_DH.con     060376519_DH
#
#                                         File Content  \
# 0  c="a workup" 27:2 27:3||t="test"\nc="pain" 55:...
# 1  c="flexeril" 39:5 39:5||t="treatment"\nc="cons...
# 2  c="ivf" 39:0 39:0||t="treatment"\nc="near sync...
# 3  c="lisinopril pump" 88:5 88:6||t="treatment"\n...
# 4  c="dizziness" 31:0 31:0||t="problem"\nc="benig...
#
#                          Manually Annotated Concepts  \
# 0  ['a workup', 'pain', 'microscopic anterior cer...
# 1  ['flexeril', 'constipation', 'left shoulder / ...
# 2  ['ivf', 'near syncope', 'recurrent dizziness',...
# 3  ['lisinopril pump', 'bipap', 'copd', 'nad', 'f...
# 4  ['dizziness', 'benign positional vertigo', 'me...
#
#                                    Concept Type List  \
# 0  ['test', 'problem', 'treatment', 'problem', 't...
# 1  ['treatment', 'problem', 'problem', 'treatment...
# 2  ['treatment', 'problem', 'problem', 'problem',...
# 3  ['treatment', 'treatment', 'problem', 'problem...
# 4  ['problem', 'problem', 'treatment', 'problem',...
#
#                                  i2b2_Annotated_CUIs  \
# 0  ['C0020473', 'C0592278', 'C0015967', 'C0728797...
# 1  ['C0012306', 'C0728797', 'C0009214', 'C0262573...
# 2  ['C0015915', 'C2263086', 'C1419864', 'C4284399...
# 3  ['C5539771', 'C3539604', 'C1623258', 'C2051415...
# 4  ['C0155502', 'C0018681', 'C0012833', 'C0015967...
#
#                                  i2b2_Annotated_TUIs  \
# 0  ['T169', 'T121', 'T201', 'T168', 'T047', 'T033...
# 1           ['T121', 'T201', 'T037', 'T184', 'T109']
# 2  ['T026', 'T028', 'T201', 'T047', 'T184', 'T061...
# 3  ['T055', 'T025', 'T201', 'T078', 'T033', 'T184...
# 4  ['T169', 'T121', 'T201', 'T033', 'T047', 'T184...
#
#                                    OpenAlex_Concepts  \
# 0  ['medicine', 'clonus', 'hyperreflexia', 'physi...
# 1  ['medicine', 'nausea', 'constipation', 'codein...
# 2  ['medicine', 'chest pain', 'weakness', 'syncop...
# 3  ['fluticasone propionate', 'chemistry', 'medic...
# 4  ['medicine', 'complaint', 'emergency departmen...
#
#                                      OpenAlex_Scores  \
# 0  [0.9112345576286316, 0.7156546115875244, 0.610...
# 1  [0.7432302832603455, 0.5929043889045715, 0.591...
# 2  [0.8295673727989197, 0.5714144706726074, 0.482...
# 3  [0.6071492433547974, 0.49507227540016174, 0.42...
# 4  [0.7121383547782898, 0.5547797679901123, 0.483...
#
#                                              OA_CUIs  \
# 0  ['C0013227', 'C0220870', 'C0038895', 'C0262926...
# 1  ['C0013227', 'C0002912', 'C0699718', 'C3864418...
# 2  ['C3714552', 'C0013227', 'C0587599', 'C0002912...
# 3  ['C0013227', 'C0002912', 'C0025118', 'C2219802...
# 4  ['C0013227', 'C0587599', 'C0022893', 'C1069915...
#
#                                              OA_TUIs  \
# 0  ['T169', 'T184', 'T058', 'T060', 'T091', 'T033...
# 1  ['T201', 'T184', 'T091', 'T033', 'T170', 'T121...
# 2  ['T201', 'T011', 'T184', 'T058', 'T091', 'T033...
# 3  ['T059', 'T169', 'T201', 'T090', 'T184', 'T033...
# 4  ['T093', 'T204', 'T201', 'T184', 'T058', 'T047...
#
#                                      cTAKES_Concepts  \
# 0  ['DIS', 'Report Status', 'DIAGNOSIS', 'HISTORY...
# 1  ['DIS', 'Report Status', 'service', 'Discharge...
# 2  ['DIS', 'Report Status', 'Yes', 'Discharge Sta...
# 3  ['DIS', 'Report Status', 'Service', 'YES', 'Sh...
# 4  ['DIS', 'Report Status', 'Discharge Status', '...
#
#                                          cTAKES_CUIs  \
# 0  ['C1444662', 'C0586177', 'C0011900', 'C0262926...
# 1  ['C1444662', 'C0586177', 'C0557854', 'C0586514...
# 2  ['C1444662', 'C0586177', 'C1298907', 'C0586514...
# 3  ['C1444662', 'C0586177', 'C0557854', 'C1298907...
# 4  ['C1444662', 'C0586177', 'C0586514', 'C0277786...
#
#                                          cTAKES_TUIs  \
# 0  ['T033', 'T033', 'T033', 'T033', 'T184', 'T033...
# 1  ['T033', 'T033', 'T057', 'T033', 'T033', 'T033...
# 2  ['T033', 'T033', 'T033', 'T033', 'T033', 'T184...
# 3  ['T033', 'T033', 'T057', 'T033', 'T184', 'T044...
# 4  ['T033', 'T033', 'T033', 'T033', 'T184', 'T184...
#
#                                          MM_Concepts  \
# 0  Oral, PO (eyeglasses), Doctor of Medicine, MG,...
# 1  Papillary craniopharyngioma, Pneumocystis jiro...
# 2  Patients, Papillary craniopharyngioma, Pneumoc...
# 3  Give - dosing instruction imperative, Then, Un...
# 4  Papillary craniopharyngioma, Pneumocystis jiro...
#
#                                              MM_CUIs  \
# 0  [C0442027, C4759839, C1512018, C4321396, C0024...
# 1  [C0431128, C1535939, C3896095, C0030705, C3274...
# 2  [C0030705, C0431128, C1535939, C3896095, C1707...
# 3  [C1947971, C1883708, C0439148, C3814390, C4049...
# 4  [C0431128, C1535939, C3896095, C1512018, C0030...
#
#                                          MM_SemTypes  \
# 0  spco, fndg, inpr, diap, diap, qnco, popg, clas...
# 1  neop, dsyn, moft, podg, hlca, inpr, inpr, fndg...
# 2  podg, neop, dsyn, moft, bodm, popg, inpr, inpr...
# 3  ftcn, tmco, qnco, inpr, mamm, inpr, qnco, qnco...
# 4  neop, dsyn, moft, inpr, podg, clna, fndg, inpr...
#
#                                              MM_TUIs
# 0  ['T082', 'T033', 'T170', 'T060', 'T060', 'T081...
# 1  ['T191', 'T047', 'T044', 'T101', 'T058', 'T170...
# 2  ['T101', 'T191', 'T047', 'T044', 'T122', 'T098...
# 3  ['T169', 'T079', 'T081', 'T170', 'T015', 'T170...
# 4  ['T191', 'T047', 'T044', 'T170', 'T101', 'T201...

# %% [markdown]
# combine CUIs and TUIs from OpenAlex and cTAKES to create ensemble dataset 1

# %%
complete_dataset.columns
# Out:
# Index(['Full File Name', 'File Name', 'File Content',
#        'Manually Annotated Concepts', 'Concept Type List',
#        'i2b2_Annotated_CUIs', 'i2b2_Annotated_TUIs', 'OpenAlex_Concepts',
#        'OpenAlex_Scores', 'OA_CUIs', 'OA_TUIs', 'cTAKES_Concepts',
#        'cTAKES_CUIs', 'cTAKES_TUIs', 'MM_Concepts', 'MM_CUIs', 'MM_SemTypes',
#        'MM_TUIs'],
#       dtype='object')

# %%
import ast
complete_dataset['i2b2_Annotated_CUIs'] = complete_dataset['i2b2_Annotated_CUIs'].apply(ast.literal_eval)
complete_dataset['i2b2_Annotated_TUIs'] = complete_dataset['i2b2_Annotated_TUIs'].apply(ast.literal_eval)

complete_dataset['OA_CUIs'] = complete_dataset['OA_CUIs'].apply(ast.literal_eval)
complete_dataset['OA_TUIs'] = complete_dataset['OA_TUIs'].apply(ast.literal_eval)

complete_dataset['cTAKES_CUIs'] = complete_dataset['cTAKES_CUIs'].apply(ast.literal_eval)
complete_dataset['cTAKES_TUIs'] = complete_dataset['cTAKES_TUIs'].apply(ast.literal_eval)

# complete_dataset['MM_CUIs'] = complete_dataset['MM_CUIs'].apply(ast.literal_eval)
complete_dataset['MM_TUIs'] = complete_dataset['MM_TUIs'].apply(ast.literal_eval)

# %%
complete_dataset.head()
# Out:
#         Full File Name        File Name  \
# 0     018636330_DH.con     018636330_DH
# 1    026350193_RWH.con    026350193_RWH
# 2    037945397_RWH.con    037945397_RWH
# 3  044687343_ELMVH.con  044687343_ELMVH
# 4     060376519_DH.con     060376519_DH
#
#                                         File Content  \
# 0  c="a workup" 27:2 27:3||t="test"\nc="pain" 55:...
# 1  c="flexeril" 39:5 39:5||t="treatment"\nc="cons...
# 2  c="ivf" 39:0 39:0||t="treatment"\nc="near sync...
# 3  c="lisinopril pump" 88:5 88:6||t="treatment"\n...
# 4  c="dizziness" 31:0 31:0||t="problem"\nc="benig...
#
#                          Manually Annotated Concepts  \
# 0  ['a workup', 'pain', 'microscopic anterior cer...
# 1  ['flexeril', 'constipation', 'left shoulder / ...
# 2  ['ivf', 'near syncope', 'recurrent dizziness',...
# 3  ['lisinopril pump', 'bipap', 'copd', 'nad', 'f...
# 4  ['dizziness', 'benign positional vertigo', 'me...
#
#                                    Concept Type List  \
# 0  ['test', 'problem', 'treatment', 'problem', 't...
# 1  ['treatment', 'problem', 'problem', 'treatment...
# 2  ['treatment', 'problem', 'problem', 'problem',...
# 3  ['treatment', 'treatment', 'problem', 'problem...
# 4  ['problem', 'problem', 'treatment', 'problem',...
#
#                                  i2b2_Annotated_CUIs  \
# 0  [C0020473, C0592278, C0015967, C0728797, C0162...
# 1  [C0012306, C0728797, C0009214, C0262573, C4255...
# 2  [C0015915, C2263086, C1419864, C4284399, C2751...
# 3  [C5539771, C3539604, C1623258, C2051415, C0302...
# 4  [C0155502, C0018681, C0012833, C0015967, C1457...
#
#                                  i2b2_Annotated_TUIs  \
# 0  [T169, T121, T201, T168, T047, T033, T184, T06...
# 1                     [T121, T201, T037, T184, T109]
# 2   [T026, T028, T201, T047, T184, T061, T059, T037]
# 3  [T055, T025, T201, T078, T033, T184, T191, T03...
# 4   [T169, T121, T201, T033, T047, T184, T060, T109]
#
#                                    OpenAlex_Concepts  \
# 0  ['medicine', 'clonus', 'hyperreflexia', 'physi...
# 1  ['medicine', 'nausea', 'constipation', 'codein...
# 2  ['medicine', 'chest pain', 'weakness', 'syncop...
# 3  ['fluticasone propionate', 'chemistry', 'medic...
# 4  ['medicine', 'complaint', 'emergency departmen...
#
#                                      OpenAlex_Scores  \
# 0  [0.9112345576286316, 0.7156546115875244, 0.610...
# 1  [0.7432302832603455, 0.5929043889045715, 0.591...
# 2  [0.8295673727989197, 0.5714144706726074, 0.482...
# 3  [0.6071492433547974, 0.49507227540016174, 0.42...
# 4  [0.7121383547782898, 0.5547797679901123, 0.483...
#
#                                              OA_CUIs  \
# 0  [C0013227, C0220870, C0038895, C0262926, C0025...
# 1  [C0013227, C0002912, C0699718, C3864418, C0949...
# 2  [C3714552, C0013227, C0587599, C0002912, C0030...
# 3  [C0013227, C0002912, C0025118, C2219802, C0117...
# 4  [C0013227, C0587599, C0022893, C1069915, C3864...
#
#                                              OA_TUIs  \
# 0  [T169, T184, T058, T060, T091, T033, T078, T12...
# 1   [T201, T184, T091, T033, T170, T121, T061, T109]
# 2   [T201, T011, T184, T058, T091, T033, T121, T061]
# 3  [T059, T169, T201, T090, T184, T033, T091, T17...
# 4  [T093, T204, T201, T184, T058, T047, T091, T03...
#
#                                      cTAKES_Concepts  \
# 0  ['DIS', 'Report Status', 'DIAGNOSIS', 'HISTORY...
# 1  ['DIS', 'Report Status', 'service', 'Discharge...
# 2  ['DIS', 'Report Status', 'Yes', 'Discharge Sta...
# 3  ['DIS', 'Report Status', 'Service', 'YES', 'Sh...
# 4  ['DIS', 'Report Status', 'Discharge Status', '...
#
#                                          cTAKES_CUIs  \
# 0  [C1444662, C0586177, C0011900, C0262926, C0221...
# 1  [C1444662, C0586177, C0557854, C0586514, C0277...
# 2  [C1444662, C0586177, C1298907, C0586514, C0277...
# 3  [C1444662, C0586177, C0557854, C1298907, C0013...
# 4  [C1444662, C0586177, C0586514, C0277786, C0012...
#
#                                          cTAKES_TUIs  \
# 0  [T033, T033, T033, T033, T184, T033, T184, T18...
# 1  [T033, T033, T057, T033, T033, T033, T184, T18...
# 2  [T033, T033, T033, T033, T033, T184, T184, T18...
# 3  [T033, T033, T057, T033, T184, T044, T184, T18...
# 4  [T033, T033, T033, T033, T184, T184, T033, T04...
#
#                                          MM_Concepts  \
# 0  Oral, PO (eyeglasses), Doctor of Medicine, MG,...
# 1  Papillary craniopharyngioma, Pneumocystis jiro...
# 2  Patients, Papillary craniopharyngioma, Pneumoc...
# 3  Give - dosing instruction imperative, Then, Un...
# 4  Papillary craniopharyngioma, Pneumocystis jiro...
#
#                                              MM_CUIs  \
# 0  [C0442027, C4759839, C1512018, C4321396, C0024...
# 1  [C0431128, C1535939, C3896095, C0030705, C3274...
# 2  [C0030705, C0431128, C1535939, C3896095, C1707...
# 3  [C1947971, C1883708, C0439148, C3814390, C4049...
# 4  [C0431128, C1535939, C3896095, C1512018, C0030...
#
#                                          MM_SemTypes  \
# 0  spco, fndg, inpr, diap, diap, qnco, popg, clas...
# 1  neop, dsyn, moft, podg, hlca, inpr, inpr, fndg...
# 2  podg, neop, dsyn, moft, bodm, popg, inpr, inpr...
# 3  ftcn, tmco, qnco, inpr, mamm, inpr, qnco, qnco...
# 4  neop, dsyn, moft, inpr, podg, clna, fndg, inpr...
#
#                                              MM_TUIs
# 0  [T082, T033, T170, T060, T060, T081, T098, T18...
# 1  [T191, T047, T044, T101, T058, T170, T170, T03...
# 2  [T101, T191, T047, T044, T122, T098, T170, T17...
# 3  [T169, T079, T081, T170, T015, T170, T081, T08...
# 4  [T191, T047, T044, T170, T101, T201, T033, T17...

# %%
# ensemble 1 dataset
complete_dataset['ensemble_1_CUIs'] = complete_dataset.apply(lambda row: list(set(row['OA_CUIs'] + row['cTAKES_CUIs'])), axis=1)
complete_dataset['ensemble_1_TUIs'] = complete_dataset.apply(lambda row: list(set(row['OA_TUIs'] + row['cTAKES_TUIs'])), axis=1)

# ensemble 2 dataset
complete_dataset['ensemble_2_CUIs'] = complete_dataset.apply(lambda row: list(set(row['OA_CUIs'] + row['MM_CUIs'])), axis=1)
complete_dataset['ensemble_2_TUIs'] = complete_dataset.apply(lambda row: list(set(row['OA_TUIs'] + row['MM_TUIs'])), axis=1)

# ensemble 3 dataset
complete_dataset['ensemble_3_CUIs'] = complete_dataset.apply(lambda row: list(set(row['OA_CUIs'] + row['cTAKES_CUIs'] + row['MM_CUIs'])), axis=1)
complete_dataset['ensemble_3_TUIs'] = complete_dataset.apply(lambda row: list(set(row['OA_TUIs'] + row['cTAKES_TUIs'] + row['MM_TUIs'])), axis=1)

# %%
complete_dataset.to_csv('.\i2b2_2010_VA_training_data\complete_dataset.csv', index=False)

# %% [markdown]
# Drop unnecessary columns

# %%
complete_dataset.columns
# Out:
# Index(['Full File Name', 'File Name', 'File Content',
#        'Manually Annotated Concepts', 'Concept Type List',
#        'i2b2_Annotated_CUIs', 'i2b2_Annotated_TUIs', 'OpenAlex_Concepts',
#        'OpenAlex_Scores', 'OA_CUIs', 'OA_TUIs', 'cTAKES_Concepts',
#        'cTAKES_CUIs', 'cTAKES_TUIs', 'MM_Concepts', 'MM_CUIs', 'MM_SemTypes',
#        'MM_TUIs', 'ensemble_1_CUIs', 'ensemble_1_TUIs', 'ensemble_2_CUIs',
#        'ensemble_2_TUIs', 'ensemble_3_CUIs', 'ensemble_3_TUIs'],
#       dtype='object')

# %%
# Define the columns to drop
columns_to_drop = ['Full File Name', 'File Content', 'Manually Annotated Concepts', 'Concept Type List',
                   'OpenAlex_Concepts', 'OpenAlex_Scores', 'cTAKES_Concepts', 'MM_Concepts', 'MM_SemTypes']

# Drop the specified columns
complete_dataset.drop(columns=columns_to_drop, inplace=True)

# %%
complete_dataset.head()
# Out:
#          File Name                                i2b2_Annotated_CUIs  \
# 0     018636330_DH  [C0020473, C0592278, C0015967, C0728797, C0162...
# 1    026350193_RWH  [C0012306, C0728797, C0009214, C0262573, C4255...
# 2    037945397_RWH  [C0015915, C2263086, C1419864, C4284399, C2751...
# 3  044687343_ELMVH  [C5539771, C3539604, C1623258, C2051415, C0302...
# 4     060376519_DH  [C0155502, C0018681, C0012833, C0015967, C1457...
#
#                                  i2b2_Annotated_TUIs  \
# 0  [T169, T121, T201, T168, T047, T033, T184, T06...
# 1                     [T121, T201, T037, T184, T109]
# 2   [T026, T028, T201, T047, T184, T061, T059, T037]
# 3  [T055, T025, T201, T078, T033, T184, T191, T03...
# 4   [T169, T121, T201, T033, T047, T184, T060, T109]
#
#                                              OA_CUIs  \
# 0  [C0013227, C0220870, C0038895, C0262926, C0025...
# 1  [C0013227, C0002912, C0699718, C3864418, C0949...
# 2  [C3714552, C0013227, C0587599, C0002912, C0030...
# 3  [C0013227, C0002912, C0025118, C2219802, C0117...
# 4  [C0013227, C0587599, C0022893, C1069915, C3864...
#
#                                              OA_TUIs  \
# 0  [T169, T184, T058, T060, T091, T033, T078, T12...
# 1   [T201, T184, T091, T033, T170, T121, T061, T109]
# 2   [T201, T011, T184, T058, T091, T033, T121, T061]
# 3  [T059, T169, T201, T090, T184, T033, T091, T17...
# 4  [T093, T204, T201, T184, T058, T047, T091, T03...
#
#                                          cTAKES_CUIs  \
# 0  [C1444662, C0586177, C0011900, C0262926, C0221...
# 1  [C1444662, C0586177, C0557854, C0586514, C0277...
# 2  [C1444662, C0586177, C1298907, C0586514, C0277...
# 3  [C1444662, C0586177, C0557854, C1298907, C0013...
# 4  [C1444662, C0586177, C0586514, C0277786, C0012...
#
#                                          cTAKES_TUIs  \
# 0  [T033, T033, T033, T033, T184, T033, T184, T18...
# 1  [T033, T033, T057, T033, T033, T033, T184, T18...
# 2  [T033, T033, T033, T033, T033, T184, T184, T18...
# 3  [T033, T033, T057, T033, T184, T044, T184, T18...
# 4  [T033, T033, T033, T033, T184, T184, T033, T04...
#
#                                              MM_CUIs  \
# 0  [C0442027, C4759839, C1512018, C4321396, C0024...
# 1  [C0431128, C1535939, C3896095, C0030705, C3274...
# 2  [C0030705, C0431128, C1535939, C3896095, C1707...
# 3  [C1947971, C1883708, C0439148, C3814390, C4049...
# 4  [C0431128, C1535939, C3896095, C1512018, C0030...
#
#                                              MM_TUIs  \
# 0  [T082, T033, T170, T060, T060, T081, T098, T18...
# 1  [T191, T047, T044, T101, T058, T170, T170, T03...
# 2  [T101, T191, T047, T044, T122, T098, T170, T17...
# 3  [T169, T079, T081, T170, T015, T170, T081, T08...
# 4  [T191, T047, T044, T170, T101, T201, T033, T17...
#
#                                      ensemble_1_CUIs  \
# 0  [C0038895, C1274039, C0239832, C0043250, C0028...
# 1  [C0002912, C0027497, C0277786, C0009806, C1547...
# 2  [C0002912, C0030755, C0277786, C0039070, C0018...
# 3  [C0150411, C0042029, C0474702, C0449208, C0905...
# 4  [C0522351, C0030755, C0277786, C0202691, C3864...
#
#                                      ensemble_1_TUIs  \
# 0  [T033, T061, T030, T122, T058, T037, T169, T09...
# 1  [T109, T047, T184, T033, T061, T190, T091, T03...
# 2  [T109, T059, T130, T047, T184, T033, T061, T03...
# 3  [T033, T061, T129, T030, T122, T090, T044, T05...
# 4  [T109, T184, T033, T093, T061, T091, T046, T02...
#
#                                      ensemble_2_CUIs  \
# 0  [C4321396, C0443246, C0332271, C0037928, C0205...
# 1  [C4552888, C0585027, C0743221, C1553384, C0443...
# 2  [C0029921, C0743221, C1513916, C5235189, C1553...
# 3  [C0150369, C4321396, C0449208, C1705169, C1705...
# 4  [C1705961, C0743221, C1513916, C4321396, C1553...
#
#                                      ensemble_2_TUIs  \
# 0  [T098, T033, T061, T034, T080, T129, T030, T12...
# 1  [T098, T033, T061, T191, T080, T122, T073, T08...
# 2  [T098, T033, T061, T034, T191, T080, T122, T06...
# 3  [T098, T033, T061, T034, T191, T080, T030, T12...
# 4  [T098, T033, T061, T034, T191, T080, T073, T08...
#
#                                      ensemble_3_CUIs  \
# 0  [C4321396, C0443246, C0332271, C0037928, C0205...
# 1  [C4552888, C0585027, C0743221, C1553384, C0443...
# 2  [C0029921, C0743221, C1513916, C5235189, C1553...
# 3  [C0150369, C4321396, C0474702, C0449208, C1705...
# 4  [C1705961, C0743221, C1513916, C4321396, C1553...
#
#                                      ensemble_3_TUIs
# 0  [T098, T033, T061, T034, T080, T129, T030, T12...
# 1  [T098, T033, T061, T191, T080, T122, T073, T08...
# 2  [T098, T033, T061, T034, T191, T080, T122, T06...
# 3  [T098, T033, T061, T034, T191, T080, T129, T03...
# 4  [T098, T033, T061, T034, T191, T080, T073, T08...

# %% [markdown]
# create calculated metrics

# %%
def calculate_metrics(df, ground_truth_col, predicted_col):
    def soft_metrics(row, gt_col, pred_col):
        gt_set = set(row[gt_col])
        pred_set = set(row[pred_col])
        intersection = len(gt_set.intersection(pred_set))
        
        precision = intersection / len(pred_set) if len(pred_set) > 0 else 0
        recall = intersection / len(gt_set) if len(gt_set) > 0 else 0
        fscore = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        
        return precision, recall, fscore

    # Apply calculation row-wise
    metrics = df.apply(lambda row: soft_metrics(row, ground_truth_col, predicted_col), axis=1)
    df[f'Soft_Precision_{ground_truth_col}_{predicted_col}'], df[f'Soft_Recall_{ground_truth_col}_{predicted_col}'], df[f'Soft_FScore_{ground_truth_col}_{predicted_col}'] = zip(*metrics)
    
    # Calculate means
    mean_precision = df[f'Soft_Precision_{ground_truth_col}_{predicted_col}'].mean() * 100
    mean_recall = df[f'Soft_Recall_{ground_truth_col}_{predicted_col}'].mean() * 100
    mean_fscore = df[f'Soft_FScore_{ground_truth_col}_{predicted_col}'].mean() * 100
    
    print(f"Mean Soft Precision_{ground_truth_col}_{predicted_col}:", round(mean_precision, 2), "%")
    print(f"Mean Soft Recall_{ground_truth_col}_{predicted_col}:", round(mean_recall, 2), "%")
    print(f"Mean Soft F-Score_{ground_truth_col}_{predicted_col}:", round(mean_fscore, 2), "%")
    
    # return{mean_precision, mean_recall, mean_fscore }
    return {
        'Mean Soft Precision (%)': mean_precision,  
        'Mean Soft Recall (%)': mean_recall,     
        'Mean Soft F-Score (%)': mean_fscore     
    }

# %%
column_pairs = [
    ('i2b2_Annotated_CUIs', 'OA_CUIs'),
    ('i2b2_Annotated_TUIs', 'OA_TUIs'),
    ('i2b2_Annotated_CUIs', 'cTAKES_CUIs'),
    ('i2b2_Annotated_TUIs', 'cTAKES_TUIs'),
    ('i2b2_Annotated_CUIs', 'MM_CUIs'),
    ('i2b2_Annotated_TUIs', 'MM_TUIs'),
    ('i2b2_Annotated_CUIs', 'ensemble_1_CUIs'),
    ('i2b2_Annotated_TUIs', 'ensemble_1_TUIs'),
    ('i2b2_Annotated_CUIs', 'ensemble_2_CUIs'),
    ('i2b2_Annotated_TUIs', 'ensemble_2_TUIs'),
    ('i2b2_Annotated_CUIs', 'ensemble_3_CUIs'),
    ('i2b2_Annotated_TUIs', 'ensemble_3_TUIs'),
    
]

# Initialize an empty dictionary to store results
results = {}

# Calculate metrics for each pair and collect results in a structured way
for ground_truth, predicted in column_pairs:
    metric_results = calculate_metrics(complete_dataset, ground_truth, predicted)
    for key, value in metric_results.items():
        if key not in results:
            results[key] = []
        results[key].append(value)

# Convert the structured results into a DataFrame
results_df = pd.DataFrame(results, index=[pair[1] for pair in column_pairs])
# Out:
# Mean Soft Precision_i2b2_Annotated_CUIs_OA_CUIs: 19.9 %
# Mean Soft Recall_i2b2_Annotated_CUIs_OA_CUIs: 7.17 %
# Mean Soft F-Score_i2b2_Annotated_CUIs_OA_CUIs: 8.59 %
# Mean Soft Precision_i2b2_Annotated_TUIs_OA_TUIs: 66.77 %
# Mean Soft Recall_i2b2_Annotated_TUIs_OA_TUIs: 29.72 %
# Mean Soft F-Score_i2b2_Annotated_TUIs_OA_TUIs: 37.04 %
# Mean Soft Precision_i2b2_Annotated_CUIs_cTAKES_CUIs: 27.95 %
# Mean Soft Recall_i2b2_Annotated_CUIs_cTAKES_CUIs: 36.94 %
# Mean Soft F-Score_i2b2_Annotated_CUIs_cTAKES_CUIs: 30.41 %
# Mean Soft Precision_i2b2_Annotated_TUIs_cTAKES_TUIs: 56.63 %
# Mean Soft Recall_i2b2_Annotated_TUIs_cTAKES_TUIs: 50.57 %
# Mean Soft F-Score_i2b2_Annotated_TUIs_cTAKES_TUIs: 51.75 %
# Mean Soft Precision_i2b2_Annotated_CUIs_MM_CUIs: 10.3 %
# Mean Soft Recall_i2b2_Annotated_CUIs_MM_CUIs: 65.5 %
# Mean Soft F-Score_i2b2_Annotated_CUIs_MM_CUIs: 17.31 %
# Mean Soft Precision_i2b2_Annotated_TUIs_MM_TUIs: 36.38 %
# Mean Soft Recall_i2b2_Annotated_TUIs_MM_TUIs: 83.29 %
# Mean Soft F-Score_i2b2_Annotated_TUIs_MM_TUIs: 48.97 %
# Mean Soft Precision_i2b2_Annotated_CUIs_ensemble_1_CUIs: 25.6 %
# Mean Soft Recall_i2b2_Annotated_CUIs_ensemble_1_CUIs: 40.51 %
# Mean Soft F-Score_i2b2_Annotated_CUIs_ensemble_1_CUIs: 29.72 %
# Mean Soft Precision_i2b2_Annotated_TUIs_ensemble_1_TUIs: 54.07 %
# Mean Soft Recall_i2b2_Annotated_TUIs_ensemble_1_TUIs: 60.51 %
# Mean Soft F-Score_i2b2_Annotated_TUIs_ensemble_1_TUIs: 54.86 %
# Mean Soft Precision_i2b2_Annotated_CUIs_ensemble_2_CUIs: 10.24 %
# Mean Soft Recall_i2b2_Annotated_CUIs_ensemble_2_CUIs: 67.38 %
# Mean Soft F-Score_i2b2_Annotated_CUIs_ensemble_2_CUIs: 17.26 %
# Mean Soft Precision_i2b2_Annotated_TUIs_ensemble_2_TUIs: 36.38 %
# Mean Soft Recall_i2b2_Annotated_TUIs_ensemble_2_TUIs: 85.64 %
# Mean Soft F-Score_i2b2_Annotated_TUIs_ensemble_2_TUIs: 49.23 %
# Mean Soft Precision_i2b2_Annotated_CUIs_ensemble_3_CUIs: 10.22 %
# Mean Soft Recall_i2b2_Annotated_CUIs_ensemble_3_CUIs: 71.6 %
# Mean Soft F-Score_i2b2_Annotated_CUIs_ensemble_3_CUIs: 17.43 %
# Mean Soft Precision_i2b2_Annotated_TUIs_ensemble_3_TUIs: 36.95 %
# Mean Soft Recall_i2b2_Annotated_TUIs_ensemble_3_TUIs: 93.73 %
# Mean Soft F-Score_i2b2_Annotated_TUIs_ensemble_3_TUIs: 51.21 %

# %%
results_df
# Out:
#                  Mean Soft Precision (%)  Mean Soft Recall (%)  \
# OA_CUIs                        19.903316              7.172149
# OA_TUIs                        66.770382             29.724164
# cTAKES_CUIs                    27.952450             36.944941
# cTAKES_TUIs                    56.631307             50.572978
# MM_CUIs                        10.300870             65.495940
# MM_TUIs                        36.380216             83.294544
# ensemble_1_CUIs                25.604323             40.509168
# ensemble_1_TUIs                54.070959             60.508748
# ensemble_2_CUIs                10.237887             67.376808
# ensemble_2_TUIs                36.381315             85.644603
# ensemble_3_CUIs                10.223702             71.596339
# ensemble_3_TUIs                36.949956             93.729748
#
#                  Mean Soft F-Score (%)
# OA_CUIs                       8.589994
# OA_TUIs                      37.042400
# cTAKES_CUIs                  30.405180
# cTAKES_TUIs                  51.749866
# MM_CUIs                      17.308699
# MM_TUIs                      48.970217
# ensemble_1_CUIs              29.715468
# ensemble_1_TUIs              54.863572
# ensemble_2_CUIs              17.263073
# ensemble_2_TUIs              49.229658
# ensemble_3_CUIs              17.426423
# ensemble_3_TUIs              51.214309

# %%
# Map system names
system_map = {
    'OA_CUIs': 'OpenAlex(OA)',
    'OA_TUIs': 'OpenAlex(OA)',
    'cTAKES_CUIs': 'cTAKES',
    'cTAKES_TUIs': 'cTAKES',
    'MM_CUIs': 'MetaMap(MM)',
    'MM_TUIs': 'MetaMap(MM)',
    'ensemble_1_CUIs': 'ensemble_1 (OA+cTAKES)',
    'ensemble_1_TUIs': 'ensemble_1 (OA+cTAKES)',
    'ensemble_2_CUIs': 'ensemble_2 (OA+MM)',
    'ensemble_2_TUIs': 'ensemble_2 (OA+MM)',
    'ensemble_3_CUIs': 'ensemble_3 (OA+cTAKES+MM)',
    'ensemble_3_TUIs': 'ensemble_3 (OA+cTAKES+MM)'
}

# Convert original data to the desired format
transformed_data = {
    'System': [],
    'Soft Recall (CUI)': [],
    'Soft Recall (TUI)': [],
    'Soft Precision (CUI)': [],
    'Soft Precision (TUI)': [],
    'Soft F-Score (CUI)': [],
    'Soft F-Score (TUI)': []
}


for index, row in results_df.iterrows():
    system = system_map[index]
    precision_cui = row['Mean Soft Precision (%)']
    recall_cui = row['Mean Soft Recall (%)']
    f1_cui = row['Mean Soft F-Score (%)']
    
    # Handle TUIs separately
    if '_CUIs' in index:
        transformed_data['System'].append(system)
        transformed_data['Soft Recall (CUI)'].append(recall_cui)
        transformed_data['Soft Precision (CUI)'].append(precision_cui)
        transformed_data['Soft F-Score (CUI)'].append(f1_cui)
    else:
        transformed_data['Soft Recall (TUI)'].append(recall_cui)
        transformed_data['Soft Precision (TUI)'].append(precision_cui)
        transformed_data['Soft F-Score (TUI)'].append(f1_cui)

# Create DataFrame
result_table = pd.DataFrame(transformed_data)

# %%
result_table
# Out:
#                       System  Soft Recall (CUI)  Soft Recall (TUI)  \
# 0               OpenAlex(OA)           7.172149          29.724164
# 1                     cTAKES          36.944941          50.572978
# 2                MetaMap(MM)          65.495940          83.294544
# 3     ensemble_1 (OA+cTAKES)          40.509168          60.508748
# 4         ensemble_2 (OA+MM)          67.376808          85.644603
# 5  ensemble_3 (OA+cTAKES+MM)          71.596339          93.729748
#
#    Soft Precision (CUI)  Soft Precision (TUI)  Soft F-Score (CUI)  \
# 0             19.903316             66.770382            8.589994
# 1             27.952450             56.631307           30.405180
# 2             10.300870             36.380216           17.308699
# 3             25.604323             54.070959           29.715468
# 4             10.237887             36.381315           17.263073
# 5             10.223702             36.949956           17.426423
#
#    Soft F-Score (TUI)
# 0           37.042400
# 1           51.749866
# 2           48.970217
# 3           54.863572
# 4           49.229658
# 5           51.214309

# %%
# Sorting the DataFrame by the 'Recall (CUI)' column in ascending order
result_table_sorted = result_table.sort_values(by='Soft Recall (CUI)')

# %%
result_table_sorted
# Out:
#                       System  Soft Recall (CUI)  Soft Recall (TUI)  \
# 0               OpenAlex(OA)           7.172149          29.724164
# 1                     cTAKES          36.944941          50.572978
# 3     ensemble_1 (OA+cTAKES)          40.509168          60.508748
# 2                MetaMap(MM)          65.495940          83.294544
# 4         ensemble_2 (OA+MM)          67.376808          85.644603
# 5  ensemble_3 (OA+cTAKES+MM)          71.596339          93.729748
#
#    Soft Precision (CUI)  Soft Precision (TUI)  Soft F-Score (CUI)  \
# 0             19.903316             66.770382            8.589994
# 1             27.952450             56.631307           30.405180
# 3             25.604323             54.070959           29.715468
# 2             10.300870             36.380216           17.308699
# 4             10.237887             36.381315           17.263073
# 5             10.223702             36.949956           17.426423
#
#    Soft F-Score (TUI)
# 0           37.042400
# 1           51.749866
# 3           54.863572
# 2           48.970217
# 4           49.229658
# 5           51.214309

# %%
complete_dataset.to_csv(r'.\i2b2_2010_VA_training_data\results_final.csv')

# %% [markdown]
# Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# sns.set_palette("pastel")  # or any other named palette
# Melt the DataFrame to make it suitable for seaborn's barplot
df_melted = result_table_sorted.melt(id_vars=["System"], var_name="Metric", value_name="Percentage")

# Plot
plt.figure(figsize=(14, 8))
sns.barplot(x="Percentage", y="Metric", hue="System", data=df_melted)
plt.title('Performance Comparison of Annotation Systems')
plt.xlabel('Percentage')
plt.ylabel('Metric')
plt.legend(title='System', title_fontsize='13', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

plt.show()

# %%
df_grouped = pd.DataFrame()

df_grouped['System'] = result_table_sorted['System']
for metric in ['Soft Precision', 'Soft Recall', 'Soft F-Score']:
    df_grouped[f'{metric} (CUI)'] = result_table_sorted[f'{metric} (CUI)']
    df_grouped[f'{metric} (TUI)'] = result_table_sorted[f'{metric} (TUI)']

# Now, let's plot the data using subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

# Colors for the bars
colors = ['skyblue', 'salmon']

# Creating each subplot
for i, metric in enumerate([ 'Soft Recall', 'Soft Precision','Soft F-Score']):
    # Subset the DataFrame for the metric
    subset = df_grouped[['System', f'{metric} (CUI)', f'{metric} (TUI)']]
    subset.set_index('System', inplace=True)
    
    # Create the bar plot
    subset.plot(kind='bar', ax=axes[i], color=colors)
    
    # Set the title and make some space for the legend
    axes[i].set_title(metric)
    axes[i].legend(loc='upper left')

# Set the y-label for the first subplot
axes[0].set_ylabel('Score (%)')

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
