# %%
# !python3 -m pip install requests requests-html
# !python3 -m pip install wheel
# !python3 -m pip install --upgrade pip
# !python3 -m pip install --upgrade build
# !git clone https://github.com/lhncbc/skr_web_python_api.git
# %cd skr_web_python_api
# !python3 -m build
# !python3 -m pip install dist/skr_web_api-0.1-py3-none-any.whl

# %% [markdown]
# Process the i2b2 text report using MetaMap(MM).

# %%
import os
from skr_web_api import Submission

def process_file(input_file, output_file, email, apikey, max_text_size=10000):
    with open(input_file, 'r', encoding='utf-8') as file:
        input_text = file.read()
    
    # Truncate input text if it exceeds the maximum allowed size
    input_text = input_text[:max_text_size]

    inst = Submission(email, apikey)
    inst.init_mm_interactive(input_text)
    response = inst.submit()

    with open(output_file, 'w') as result_file:
        result_file.write(response.content.decode())

def process_folder(input_folder, output_folder, email, apikey):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Process each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".txt"):
            input_file = os.path.join(input_folder, filename)
            output_file = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_output.txt")

            process_file(input_file, output_file, email, apikey)

if __name__ == "__main__":
    # Specify your email and API key
    email = 'azizulkawser.aust@gmail.com'
    apikey = 'efd9c726-5226-43c1-8cb1-c5ac40bae98c'

    # Specify the input and output folders
    input_folder = ".\i2b2_2010_VA_training_data\consolidated_text_reports_training_data"
    output_folder = ".\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing"

    # Process the folder
    process_folder(input_folder, output_folder, email, apikey)

# %% [markdown]
# Extract required information from MM output and create single database

# %%
import os
import csv

def parse_input_file(file_path):
    with open(file_path, 'r') as file:
        data = file.readlines()[1:]
    return data

def format_line(line):
    parts = line.split("|")
    formatted_output = [part.strip() for part in parts]
    return formatted_output

def process_text_files_to_csv(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith(".txt"):
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, f"{filename[:-4]}.csv")
            
            parsed_data = parse_input_file(input_file_path)
            
            with open(output_file_path, 'w', newline='') as csvfile:
                csv_writer = csv.writer(csvfile, delimiter=';')
                csv_writer.writerow(["user", "mm", "score", "preferred_name", "cui", "semtypes", "trigger", "location", "pos_info"])
                
                for item in parsed_data:
                    formatted_line = format_line(item)
                    csv_writer.writerow(formatted_line)
            
            print(f"Formatted output saved to {output_file_path}")

def parse_input_csv(input_file_path):
    with open(input_file_path, 'r', newline='') as csvfile:
        csv_reader = csv.reader(csvfile, delimiter=';')
        header_line = next(csv_reader)
        header = [column for column in header_line]
        data = list(csv_reader)
    return header, data

# def process_data(header, data):
#     try:
#         mm_index = header.index("mm")
#         preferred_name_index = header.index("preferred_name")
#         cui_index = header.index("cui")
#         semtypes_index = header.index("semtypes")
#     except ValueError as e:
#         print("Column not found in header:", e)
#         return [], [], []

#     preferred_names, cuis, semtypes = [], [], []
    
#     for row in data:
#         if row[mm_index] == "MMI":
#             preferred_names.append(row[preferred_name_index])
#             cuis.append(row[cui_index])
#             semtypes.append(row[semtypes_index])
    
#     return preferred_names, cuis, semtypes

def process_data(header, data):
    try:
        mm_index = header.index("mm")
        preferred_name_index = header.index("preferred_name")
        cui_index = header.index("cui")
        semtypes_index = header.index("semtypes")
    except ValueError as e:
        print("Column not found in header:", e)
        return [], [], []

    preferred_names, cuis, semtypes = [], [], []
    
    for row in data:
        if row[mm_index] == "MMI":
            preferred_names.append(row[preferred_name_index])
            cuis.append(row[cui_index])
            # Remove square brackets from SemTypes
            cleaned_semtypes = row[semtypes_index].replace("[", "").replace("]", "")
            semtypes.append(cleaned_semtypes)
    
    return preferred_names, cuis, semtypes

def export_to_combined_csv(output_file_path, combined_data):
    with open(output_file_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(["File Name", "Preferred Names", "CUIs", "SemTypes"])
        
        for file_name, preferred_names, cuis, semtypes in combined_data:
            csv_writer.writerow([file_name, ", ".join(preferred_names), ", ".join(cuis), ", ".join(semtypes)])
    
    print(f"Combined data exported to: {output_file_path}")

def process_combined_folder(input_folder, output_folder):
    combined_data = []
    
    for filename in os.listdir(input_folder):
        if filename.endswith(".csv"):
            input_file_path = os.path.join(input_folder, filename)
            header, data = parse_input_csv(input_file_path)
            preferred_names, cuis, semtypes = process_data(header, data)
            combined_data.append((filename[:-4], preferred_names, cuis, semtypes))
    
    output_file_path = os.path.join(output_folder, "i2b2_text_parsed_concepts_MM.csv")
    export_to_combined_csv(output_file_path, combined_data)

# usage
text_files_input_folder = ".\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing"
csv_output_folder = ".\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output"
exported_data_folder = ".\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\MM_output"

process_text_files_to_csv(text_files_input_folder, csv_output_folder)
process_combined_folder(csv_output_folder, exported_data_folder)
# Out:
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\018636330_DH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\026350193_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\037945397_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\044687343_ELMVH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\060376519_DH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\095889687_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\101407944_PUMC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\105732749_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\115026438_SC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\130959255_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\134300717_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\143748600_SC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\145980160_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\156406283_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\176318078_a_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\176746010_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\188543380_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\194442600_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\212512774_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\223159990_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\245096078_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\245317863_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\262182942_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\262912613_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\270045381_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\274230067_EH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\284487129_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\289811204_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\297228405_DH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\306968218_YC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\320422564_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\332803550_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\333521954_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\337702516_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\346176858_SC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\348301810_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\351853846_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\373254497_PUMC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\384729825_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\388755206_SC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\402389409_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\405507617_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\405868244_YC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\412141256_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\424729395_DH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\425680098_SC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\433651389_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\455343475_PUMC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\493597270_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\498710998_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\500472963_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\503651854_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\517414339_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\523704694_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\544907529_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\555509347_PUMC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\574700124_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\596437842_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\598403789_DH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\614746156_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\622086964_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\627258104_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\638157550_SC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\641557794_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\655358166_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\688127038_EH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\693008750_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\699905656_SC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\708739405_DH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\723989226_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\745431641_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\745701560_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\767751445_ELMVH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\779878634_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\788268693_DH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\814743340_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\817406016_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\825330116_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\837898389_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\839999049_YC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\843566350_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\853262744_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\869436718_SC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\879492218_YC_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\888428725_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\891864133_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\910458031_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\915093496_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\917989835_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\920798564_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\932057504_DH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\950452368_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\959086752_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\965367286_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\974381789_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\979440029_RWH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\989519730_WGH_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-105_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-106_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-107_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-108_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-109_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-121_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-122_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-123_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-124_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-13_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-140_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-141_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-142_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-143_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-144_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-14_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-15_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-16_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-175_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-176_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-177_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-178_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-179_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-17_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-18_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-19_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-20_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-21_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-22_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-23_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-24_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-25_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-26_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-27_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-28_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-29_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-30_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-31_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-32_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-33_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-34_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-35_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-36_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-37_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-38_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-45_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-46_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-47_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-48_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-49_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-50_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-51_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-52_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-53_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-54_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-55_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-56_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-58_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-59_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-65_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-66_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-67_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-68_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-69_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-70_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-71_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-73_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-74_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-80_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-81_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-82_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-83_output.csv
# Formatted output saved to .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\record-84_output.csv
# Combined data exported to: .\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\MM_output\i2b2_text_parsed_concepts_MM.csv

# %% [markdown]
# load the database for processing

# %%
import pandas as pd
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = ".\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\MM_output\i2b2_text_parsed_concepts_MM.csv"

# Load CSV into DataFrame
df = pd.read_csv(csv_file_path)

# %%
df.head()
# Out:
#                 File Name                                    Preferred Names  \
# 0     018636330_DH_output  Oral, PO (eyeglasses), Doctor of Medicine, MG,...
# 1    026350193_RWH_output  Papillary craniopharyngioma, Pneumocystis jiro...
# 2    037945397_RWH_output  Patients, Papillary craniopharyngioma, Pneumoc...
# 3  044687343_ELMVH_output  Give - dosing instruction imperative, Then, Un...
# 4     060376519_DH_output  Papillary craniopharyngioma, Pneumocystis jiro...
#
#                                                 CUIs  \
# 0  C0442027, C4759839, C1512018, C4321396, C00246...
# 1  C0431128, C1535939, C3896095, C0030705, C32745...
# 2  C0030705, C0431128, C1535939, C3896095, C17076...
# 3  C1947971, C1883708, C0439148, C3814390, C40490...
# 4  C0431128, C1535939, C3896095, C1512018, C00307...
#
#                                             SemTypes
# 0  spco, fndg, inpr, diap, diap, qnco, popg, clas...
# 1  neop, dsyn, moft, podg, hlca, inpr, inpr, fndg...
# 2  podg, neop, dsyn, moft, bodm, popg, inpr, inpr...
# 3  ftcn, tmco, qnco, inpr, mamm, inpr, qnco, qnco...
# 4  neop, dsyn, moft, inpr, podg, clna, fndg, inpr...

# %% [markdown]
# Load the mapping file for Semantic type abbreviations to TUI.

# %%
# Specify the file path
file_path = ".\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\MM_output\SemanticTypes_2018AB.txt"

# Read the text file into a DataFrame
df_sem_type = pd.read_csv(file_path, sep='|', header=None, names=['SemTypes', 'TUI', 'Description'])

# Display the DataFrame
print(df_sem_type)
# Out:
#     SemTypes   TUI                          Description
# 0       aapp  T116      Amino Acid, Peptide, or Protein
# 1       acab  T020                 Acquired Abnormality
# 2       acty  T052                             Activity
# 3       aggp  T100                            Age Group
# 4       amas  T087                  Amino Acid Sequence
# ..       ...   ...                                  ...
# 122     tmco  T079                     Temporal Concept
# 123     topp  T061  Therapeutic or Preventive Procedure
# 124     virs  T005                                Virus
# 125     vita  T127                              Vitamin
# 126     vtbt  T010                           Vertebrate
#
# [127 rows x 3 columns]

# %%
SemTypes_to_cTUI_mapping = dict(zip(df_sem_type['SemTypes'], df_sem_type['TUI']))

# %%
df['TUIs'] = df['SemTypes'].apply(lambda x: [SemTypes_to_cTUI_mapping.get(code, code) for code in x.split(', ') if code in SemTypes_to_cTUI_mapping])

# %%
df
# Out:
#                   File Name  \
# 0       018636330_DH_output
# 1      026350193_RWH_output
# 2      037945397_RWH_output
# 3    044687343_ELMVH_output
# 4       060376519_DH_output
# ..                      ...
# 165        record-80_output
# 166        record-81_output
# 167        record-82_output
# 168        record-83_output
# 169        record-84_output
#
#                                        Preferred Names  \
# 0    Oral, PO (eyeglasses), Doctor of Medicine, MG,...
# 1    Papillary craniopharyngioma, Pneumocystis jiro...
# 2    Patients, Papillary craniopharyngioma, Pneumoc...
# 3    Give - dosing instruction imperative, Then, Un...
# 4    Papillary craniopharyngioma, Pneumocystis jiro...
# ..                                                 ...
# 165  Infant, GDC Treatment Outcome Terminology, To,...
# 166  Patients, +2, 2+, 2+ Score, 2+ Score, WHO, PSA...
# 167  AKR1B10 gene, HAL gene, Histidine measurement,...
# 168  Daily, Tablet Dosage Form, Tablet (unit of pre...
# 169  Patients, GDC Treatment Outcome Terminology, T...
#
#                                                   CUIs  \
# 0    C0442027, C4759839, C1512018, C4321396, C00246...
# 1    C0431128, C1535939, C3896095, C0030705, C32745...
# 2    C0030705, C0431128, C1535939, C3896095, C17076...
# 3    C1947971, C1883708, C0439148, C3814390, C40490...
# 4    C0431128, C1535939, C3896095, C1512018, C00307...
# ..                                                 ...
# 165  C0021270, C5202850, C1883351, C0041260, C42885...
# 166  C0030705, C0740116, C3833492, C2827735, C29817...
# 167  C1412323, C1415465, C0523697, C0019602, C08099...
# 168  C0332173, C0039225, C4319774, C4722631, C17052...
# 169  C0030705, C5202850, C1883351, C0041260, C04395...
#
#                                               SemTypes  \
# 0    spco, fndg, inpr, diap, diap, qnco, popg, clas...
# 1    neop, dsyn, moft, podg, hlca, inpr, inpr, fndg...
# 2    podg, neop, dsyn, moft, bodm, popg, inpr, inpr...
# 3    ftcn, tmco, qnco, inpr, mamm, inpr, qnco, qnco...
# 4    neop, dsyn, moft, inpr, podg, clna, fndg, inpr...
# ..                                                 ...
# 165  aggp, inpr, qlco, aapp,enzy, qlco, qlco, acty,...
# 166  podg, qnco, fndg, fndg, fndg, lbtr, fndg, fndg...
# 167  gngm, gngm, lbpr, aapp,bacs,phsu, hlca, hlca, ...
# 168  tmco, bodm, qnco, bodm, qnco, fndg, fndg, fndg...
# 169  podg, inpr, qlco, aapp,enzy, tmco, tmco, tmco,...
#
#                                                   TUIs
# 0    [T082, T033, T170, T060, T060, T081, T098, T18...
# 1    [T191, T047, T044, T101, T058, T170, T170, T03...
# 2    [T101, T191, T047, T044, T122, T098, T170, T17...
# 3    [T169, T079, T081, T170, T015, T170, T081, T08...
# 4    [T191, T047, T044, T170, T101, T201, T033, T17...
# ..                                                 ...
# 165  [T100, T170, T080, T080, T080, T052, T058, T07...
# 166  [T101, T081, T033, T033, T033, T034, T033, T03...
# 167  [T028, T028, T059, T058, T058, T033, T033, T03...
# 168  [T079, T122, T081, T122, T081, T033, T033, T03...
# 169  [T101, T170, T080, T079, T079, T079, T052, T17...
#
# [170 rows x 5 columns]

# %% [markdown]
# Save data as csv

# %%
df.to_csv('.\i2b2_2010_VA_training_data\i2b2_text_reports_MM_processing\csv_output\MM_output\i2b2_text_parsed_concepts_MM.csv', index=False)
