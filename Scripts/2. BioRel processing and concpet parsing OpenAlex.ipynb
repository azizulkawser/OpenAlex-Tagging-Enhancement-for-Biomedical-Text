# %% [markdown]
# Prepare the text report in a format suitable for input to the OpenAlex concept tagging model.

# %%
import os
import json

# Specify the input folder containing the text files and the output folder for the JSON files
input_folder_path = r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_text_data" 
output_folder_path = r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_text_data/text_reports_OpenAlex_processing" 

# Ensure the output folder exists, create if it doesn't
os.makedirs(output_folder_path, exist_ok=True)

# Loop through each file in the input folder
for filename in os.listdir(input_folder_path):
    if filename.endswith(".txt"):
        # Construct the full file path
        file_path = os.path.join(input_folder_path, filename)
        
        # Read the content of the text file
        with open(file_path, 'r', encoding='utf-8') as file:
            abstract_text = file.read()
        
        # Create a JSON object
        json_data = [{
            "title": None,
            "doc_type": None,
            "journal": None,
            "abstract": abstract_text,
            "inverted_abstract": False,
            "paper_id": None
        }]
        
        # Construct the output file name and path (.txt replaced with .json)
        output_file_name = os.path.splitext(filename)[0] + '.json'
        output_file_path = os.path.join(output_folder_path, output_file_name)
        
        # Save the JSON object to a file
        with open(output_file_path, 'w', encoding='utf-8') as json_file:
            json.dump(json_data, json_file, indent=2, ensure_ascii=False)
print("Conversion completed.")
# Out:
# Conversion completed.

# %% [markdown]
# Run the model and predict concepts for each text report.
#
# Run the flask server.
# Install Flask and Dependencies --> pip install Flask tensorflow pandas numpy
# Set Flask Environment Variables (windows cmd) --> set FLASK_APP=app.py
#                                     set FLASK_ENV=development
# Run the Flask Application --> flask run

# %%
import os
import requests

# Specify the folder containing the JSON files and where to save the responses
json_folder_path = r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_text_data/text_reports_OpenAlex_processing"

response_folder_path = r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_text_data/text_reports_OpenAlex_processing/OpenAlex_output"


# Ensure the response folder exists, create if it doesn't
os.makedirs(response_folder_path, exist_ok=True)

# The URL of your Flask application's /invocations endpoint
url = 'http://127.0.0.1:5000/invocations'

# Loop through each JSON file in the folder
for filename in os.listdir(json_folder_path):
    if filename.endswith(".json"):
        json_file_path = os.path.join(json_folder_path, filename)
        
        # Read the JSON file content
        with open(json_file_path, 'r', encoding='utf-8') as json_file:
            json_data = json_file.read()
        
        # Send the POST request with JSON data
        headers = {'Content-Type': 'application/json'}
        response = requests.post(url, data=json_data, headers=headers)
        
        # Check if the request was successful
        if response.status_code == 200:
            # Construct the response file name (.json replaced with _response.json)
            response_file_name = os.path.splitext(filename)[0] + '.json'
            response_file_path = os.path.join(response_folder_path, response_file_name)
            
            # Save the response content to a new file
            with open(response_file_path, 'w', encoding='utf-8') as response_file:
                response_file.write(response.text)
            print(f"Response for {filename} saved successfully.")
        else:
            print(f"Failed to get a response for {filename}. Status code: {response.status_code}")
print("All done.")
# Out:
# Response for 000ccbf4-2c18-4d38-932b-a7521855ba75.json saved successfully.
# Response for 0017c8ae-2d34-4a3b-9935-57eb71cb5e3e.json saved successfully.
# Response for 002191df-1e2f-4947-97ce-c1484ed8e8fe.json saved successfully.
# Response for 0036fdaf-627c-41ec-8fed-a5f3e7962768.json saved successfully.
# Response for 00376492-8a56-4d02-9417-d9f42f90b3b2.json saved successfully.
# Response for 00540d0f-b986-4d6b-bc57-ea78a5f819e4.json saved successfully.
# Response for 005aa28d-d3e5-4df4-a91f-ed6c64c1bc78.json saved successfully.
# Response for 0060558a-f0af-4e16-9737-84f1c3d3f95c.json saved successfully.
# Response for 0063bb1f-10f7-4fda-9a87-12937fad72e7.json saved successfully.
# Response for 0069a702-1a9c-4384-a4f8-aeb5a00b10e4.json saved successfully.
# Response for 007612fb-f7d4-41e2-bd97-e681f623d5ae.json saved successfully.
# Response for 0077cf43-98c7-47e1-958c-d6e463c55ff4.json saved successfully.
# Response for 007ab615-609c-4703-a740-6d48fd9b60e8.json saved successfully.
# Response for 00817c35-b348-4c0c-ae73-143334075b31.json saved successfully.
# Response for 00830bb5-1327-4ffe-853a-be0af8bce04c.json saved successfully.
# Response for 00d13554-ad8b-4e9b-bdb8-f26ae59dc5c3.json saved successfully.
# Response for 00e4da9f-4dd2-4591-9f2c-028a07dba374.json saved successfully.
# Response for 00ee255e-37c9-4efc-b295-e017036161b4.json saved successfully.
# Response for 01081321-a790-45c2-a1de-713cb1419c55.json saved successfully.
# Response for 0112bf83-749b-4eb8-baca-05ff3e8d621b.json saved successfully.
# Response for 0116233d-057b-43b8-ab26-aa7e1ccb5324.json saved successfully.
# Response for 011cc6c2-b987-4756-bb5f-83f6b0c0e879.json saved successfully.
# Response for 0122e0a6-a628-453c-83ae-d04dbae54a48.json saved successfully.
# Response for 012da390-b739-4ed0-8e24-07eef8bf6b18.json saved successfully.
# Response for 0136af12-71de-4ce7-92e3-024064f0bbf4.json saved successfully.
# Response for 013a7fe1-eacd-4a9c-aca9-d5926005fbed.json saved successfully.
# Response for 013c464a-c193-4fe5-bb6a-9bbc902b5040.json saved successfully.
# Response for 0142a1ea-4bdd-462c-8118-c780715257d4.json saved successfully.
# Response for 0144ada8-c4f9-4de5-93b7-2ae4838a6e33.json saved successfully.
# Response for 01636a0c-edf1-4a56-9ce7-43dae1562859.json saved successfully.
# Response for 016dd5a0-0a77-4657-9482-3e1d09cfe356.json saved successfully.
# Response for 01801ae4-6e06-4b53-b9ec-f283050e0a01.json saved successfully.
# Response for 0181b5bc-d476-465b-b6f5-c4f66fbc32d0.json saved successfully.
# Response for 018adaa3-d4fb-4306-9f80-7974d4fa868b.json saved successfully.
# Response for 018fcda7-7570-4c28-abd7-e93508574c68.json saved successfully.
# Response for 01b1ca9b-aa15-4740-9e84-31daff72f475.json saved successfully.
# Response for 01b54e55-6f04-425f-9da7-6a1e311d178b.json saved successfully.
# Response for 01be8f6d-52bc-4409-ac4d-abefa79027b2.json saved successfully.
# Response for 01c42509-8e8a-47c9-b5a1-b81351f7d15f.json saved successfully.
# Response for 01c9ef3a-de06-414d-b448-1f9a00a1a0fe.json saved successfully.
# Response for 01e20cc0-1410-4016-9520-c72e097f1ace.json saved successfully.
# Response for 01e6d716-7df7-4740-927a-a93ac3030a4e.json saved successfully.
# Response for 01f671a5-13e6-4d6a-a531-88dd83a27a5e.json saved successfully.
# Response for 020314aa-2b38-4d05-b31d-b201540cc28e.json saved successfully.
# Response for 02058fff-7513-42db-9f0e-e9205d1c4875.json saved successfully.
# Response for 0213d369-405f-4482-8205-36dffb8fb5ad.json saved successfully.
# Response for 0214111c-e20b-4c0c-9d90-aebec17c6826.json saved successfully.
# Response for 0214f4ea-4532-4db8-a9d5-98fa7a088c30.json saved successfully.
# Response for 02157134-85c0-46a7-a07f-1e781855dcd8.json saved successfully.
# Response for 021785a5-719c-4b76-b4c8-23a20d490028.json saved successfully.
# Response for 0218ca0b-1bed-4875-bf3c-9e74be51a6f1.json saved successfully.
# Response for 0258f053-8e74-4115-b3a6-7ac79824de9b.json saved successfully.
# Response for 0259f8e8-7b29-4b93-8059-8c58973ee4a8.json saved successfully.
# Response for 027a16cd-3430-41a4-89c4-231296982e44.json saved successfully.
# Response for 028aa4a9-d30f-4610-9d61-a877e1f5a239.json saved successfully.
# Response for 029619eb-c876-4d92-bd24-082346564ffc.json saved successfully.
# Response for 029cae52-015e-4d41-917c-8c6047d718c7.json saved successfully.
# Response for 02b1d3f2-9cab-40f7-ad5e-ac0babc923cf.json saved successfully.
# Response for 02bc377a-a745-45db-9c83-991110a5330e.json saved successfully.
# Response for 02c6eaff-211c-463b-8621-bc7c48e0c81f.json saved successfully.
# Response for 02c991b3-a480-473a-93b7-4cba1927d098.json saved successfully.
# Response for 02d2f327-b266-4d89-9d86-334914ab3816.json saved successfully.
# Response for 02d3083c-194a-4f84-af4d-df588862e5ad.json saved successfully.
# Response for 02dbc72e-0733-4bd4-91d6-1cb29e921d16.json saved successfully.
# Response for 02dd81e0-2147-4d2c-b49a-39c522d81893.json saved successfully.
# Response for 02e14000-27c0-41c7-a65b-7cb99c950179.json saved successfully.
# Response for 02ed1a6b-379b-4e53-8b34-e000416c10d2.json saved successfully.
# Response for 02f6bea6-d58f-4db0-9d12-0ddee8c9f3f7.json saved successfully.
# Response for 02fbe607-6ef2-4b04-8260-3ad1c05244b2.json saved successfully.
# Response for 02fc499b-19cf-4a2d-992f-8ceb23ac97eb.json saved successfully.
# Response for 02fc8892-3ff4-4b8f-91ac-76263e555e1d.json saved successfully.
# Response for 030d9a7c-d99a-4f92-af99-d65a5d0ce859.json saved successfully.
# Response for 031325a8-eeef-4b1d-8e5f-987318e7f752.json saved successfully.
# Response for 0324666d-dda9-473f-a183-734b72873319.json saved successfully.
# Response for 032504fe-f86d-4c94-a09a-383be3caf5a5.json saved successfully.
# Response for 033121e6-4c8a-4d9f-9f93-83e61748e3ad.json saved successfully.
# Response for 03361d51-3182-4c95-bd48-9790416b620d.json saved successfully.
# Response for 03368a04-9d20-4b74-befb-584239a0f379.json saved successfully.
# Response for 033d6cfb-ebd8-4ff6-8c3e-53e8f6b48869.json saved successfully.
# Response for 034345fe-53ee-4c93-899a-1df78a7451f9.json saved successfully.
# Response for 034fe469-213d-42fa-91c0-d3318a89dc07.json saved successfully.
# Response for 0370a255-c6d0-4791-a685-9f6cb4315713.json saved successfully.
# Response for 0371023c-c065-4080-8cf7-2144008c75c0.json saved successfully.
# Response for 0379ac6e-9fde-4e91-acf5-7a62a3556db3.json saved successfully.
# Response for 0379e554-ce68-44a4-bb56-d00781c13835.json saved successfully.
# Response for 03815c8a-14d3-435f-a850-e195666782fc.json saved successfully.
# Response for 03844ddd-c17a-419f-b1fe-41cb902a252c.json saved successfully.
# Response for 03874344-7590-471d-bcd1-164c2de05bca.json saved successfully.
# Response for 0389c1b9-4e77-40be-a918-0a5ae4638e3d.json saved successfully.
# Response for 039befe5-6981-4fbb-a035-b6d5eba42aae.json saved successfully.
# Response for 039d77b1-3493-4f8d-b009-47b4e8f8f051.json saved successfully.
# Response for 03a1fca3-1015-4177-824d-0f1e7c7ec454.json saved successfully.
# Response for 03bd9530-5b7c-4437-b693-772e5300cd51.json saved successfully.
# Response for 03c6073b-3245-4bbb-9a1e-0e6dbbeb15ab.json saved successfully.
# Response for 03c66bcb-0d56-472f-aaea-db0d08498452.json saved successfully.
# Response for 03c85337-4c11-411e-be97-466c7690e944.json saved successfully.
# Response for 03d894c7-1894-4d88-b4ae-e891815023df.json saved successfully.
# Response for 03df4d32-4dc7-4db9-a6ae-7b424069e721.json saved successfully.
# Response for 03fc82f6-2354-4e3a-af95-d1135421b9ef.json saved successfully.
# Response for 0404a05f-1dfa-44a5-a3c0-573934c9789c.json saved successfully.
# Response for 041294e4-3ce8-47be-a190-2f19d58031b8.json saved successfully.
# Response for 0424c1b3-8371-4bb1-b8ce-1a4f56d8648d.json saved successfully.
# Response for 0428cb77-5dd2-41d3-8cd5-25b5e6e724cf.json saved successfully.
# Response for 0429bcc3-b5f8-4676-8c3a-e2dfea053b8d.json saved successfully.
# Response for 042cc948-40f0-4cef-9ae9-44e78e102475.json saved successfully.
# Response for 0430f5b7-f9ad-4034-846e-d46d87cb0512.json saved successfully.
# Response for 0434eb17-14a4-45f6-a494-1cc776731d42.json saved successfully.
# Response for 04591797-d176-461b-9c28-055c81466d1a.json saved successfully.
# Response for 04591a50-dba5-46e6-9fec-b4cba494505a.json saved successfully.
# Response for 045a37a7-33da-4644-a0e1-bc6f2826756e.json saved successfully.
# Response for 045e3b8a-ab21-4f55-a93f-4305c861c36d.json saved successfully.
# Response for 045f8f1b-ef8e-4662-aaca-7fbf1a1087c4.json saved successfully.
# Response for 0470ed73-5889-4dcc-8e24-636ffe7ae5de.json saved successfully.
# Response for 0472e9ce-c6f9-4bc6-82a6-372d631d6f1e.json saved successfully.
# Response for 047dc4e5-ee2d-4a49-abb0-7394a55642c4.json saved successfully.
# Response for 0481f817-eb5a-406c-92dc-ee2cab755a25.json saved successfully.
# Response for 04924865-ccff-489b-8ce7-0bbb20910e9a.json saved successfully.
# Response for 0494450b-cb3b-4452-a2e4-9a1df93a0d7b.json saved successfully.
# Response for 04976e4b-a744-4864-8492-75e202bce2f3.json saved successfully.
# Response for 049ab05f-0032-48c0-92a9-24b4836d99b8.json saved successfully.
# Response for 04c13bb8-b967-4c5d-a271-99cf07610271.json saved successfully.
# Response for 04d32d53-eb09-4f8c-b361-d301b6f776f0.json saved successfully.
# Response for 04d84bea-176a-4e0b-956f-c422dff7c91a.json saved successfully.
# Response for 04f113d5-38e0-4922-866a-79ac7771836a.json saved successfully.
# Response for 050312a1-0328-4418-ab02-44c116db8a89.json saved successfully.
# Response for 052c89b1-930d-4015-abc4-9dccc26280ae.json saved successfully.
# Response for 05305bb3-a914-444c-ad54-d1e10072dc27.json saved successfully.
# Response for 053515d7-b63f-4669-8cd7-5efa3a38ae79.json saved successfully.
# Response for 053910ba-5fda-4aef-b94b-5df70621fe17.json saved successfully.
# Response for 053c4602-a4ea-469e-8a59-dcc625b40ae9.json saved successfully.
# Response for 05429a9f-dcf7-493b-8052-258fad608e7e.json saved successfully.
# Response for 054af036-810f-482d-809b-7455536420db.json saved successfully.
# Response for 055312be-1fe4-47a3-b167-759e2a298b9f.json saved successfully.
# Response for 0555dd2e-9cbc-496d-b509-e937f4c4707b.json saved successfully.
# Response for 0558abda-2c92-4f4b-87bc-96a2e045a87e.json saved successfully.
# Response for 0558bf67-8e3c-46eb-ac28-fa39b438b87f.json saved successfully.
# Response for 055fd0da-8ab1-4f37-9519-396f0b6a0466.json saved successfully.
# Response for 056f8d53-0960-4997-9654-4656d6b3e839.json saved successfully.
# Response for 05777a30-1a3d-49ff-9b1c-be2190e8d938.json saved successfully.
# Response for 0587c9cc-c35b-4abd-8891-728ca9dde7ce.json saved successfully.
# Response for 0594003a-bc35-4cb0-8afb-23a9f9cfa1bd.json saved successfully.
# Response for 05ab005c-356f-485b-8881-123687671630.json saved successfully.
# Response for 05ac01f2-c8c1-4bd5-9682-d499ad7cbe02.json saved successfully.
# Response for 05bdd8cd-827d-47bc-9fdd-7030caa8e0b4.json saved successfully.
# Response for 05be238a-8c77-4efe-952e-0dfabfef80aa.json saved successfully.
# Response for 05c37be7-adcd-41ac-8851-fe9280900451.json saved successfully.
# Response for 05c52205-9025-4110-87d0-6d5bd028945b.json saved successfully.
# Response for 05d88a3b-8244-4347-a042-2a16552c906c.json saved successfully.
# Response for 05ddb1e5-ae0d-4451-9764-e823d1400586.json saved successfully.
# Response for 05e865ff-acc0-4d0f-a2c2-b4f6cfcf0a71.json saved successfully.
# Response for 05ee3df8-75d6-45c6-b9fc-a31c754447d8.json saved successfully.
# Response for 05f71122-fee8-4256-b12c-b85a0a636909.json saved successfully.
# Response for 05f92c63-86ee-444b-9350-f7f518a80353.json saved successfully.
# Response for 05fa8924-4a13-4e67-942e-b4b9aebf3dda.json saved successfully.
# Response for 05ff7b8a-3c4a-4d7e-98c4-c330d687673e.json saved successfully.
# Response for 0607281c-927a-4765-b9a1-68c5463939fa.json saved successfully.
# Response for 0608ae33-88be-42f1-b1a6-e6095129be1f.json saved successfully.
# Response for 060e2d0b-b3fd-4aa2-a296-eb4480d0e531.json saved successfully.
# Response for 06154dcf-0cab-4eba-92a0-5cce9bdbaf2a.json saved successfully.
# Response for 061b4eaf-e586-46dd-b27e-30f4ec23adc9.json saved successfully.
# Response for 061ecb92-aefb-42dc-a090-40ea4d6a1eed.json saved successfully.
# Response for 062680ff-2280-4041-9fbd-677b002bec50.json saved successfully.
# Response for 063f1222-780d-44b3-a77e-00633d787d02.json saved successfully.
# Response for 063f8655-ba47-45dd-9ac2-25a29d190243.json saved successfully.
# Response for 064a8151-9b50-4708-8bb2-2a4c4eaa8728.json saved successfully.
# Response for 064d623a-9b66-44b4-b3da-6bf800f7b08b.json saved successfully.
# Response for 064f1fb2-d41e-4bc7-90da-07a4a2e370ce.json saved successfully.
# Response for 0651995f-091d-4b76-b868-a052c669a17f.json saved successfully.
# Response for 0652f78a-47b5-46e1-94ed-fdcc1b32040f.json saved successfully.
# Response for 065d716b-322d-4c3c-a783-a043ef1a5143.json saved successfully.
# Response for 065ffbb8-580c-4b44-bc30-5ade85e6dad3.json saved successfully.
# Response for 06620636-c4cc-4911-abf1-f4462b72cc16.json saved successfully.
# Response for 066369e2-a847-46c2-b9de-f78f52d74f1d.json saved successfully.
# Response for 0665c5ed-cc25-47c9-a890-cb6017b5d368.json saved successfully.
# Response for 066c1378-b758-4f99-a467-e94d35d324f4.json saved successfully.
# Response for 066c1e21-5e75-431b-992f-5b8caccade3e.json saved successfully.
# Response for 0676ccee-35ea-4930-90b9-3359492c70aa.json saved successfully.
# Response for 06816e5e-867d-4dfb-a9c7-d6efe1e8f6ad.json saved successfully.
# Response for 0683c926-eef4-42bd-b072-a92d8a0d7ccc.json saved successfully.
# Response for 068dbc7e-68df-4eab-b679-41ae2ed2cc57.json saved successfully.
# Response for 069747f1-1931-4fe0-afd7-f3c9d9d1b213.json saved successfully.
# Response for 069bd869-e9e2-44e8-a6af-7b087e5fdb10.json saved successfully.
# Response for 069f382c-8d4d-4811-8146-0b29bbf5fe48.json saved successfully.
# Response for 06a2c9fb-b899-4105-87c3-73a7bd398e02.json saved successfully.
# Response for 06a8d002-4a53-4009-919e-7410487d639e.json saved successfully.
# Response for 06a925c1-b873-47ea-b321-aefc29a88ff8.json saved successfully.
# Response for 06abb46e-cae1-41ef-9b0b-da5b22a51597.json saved successfully.
# Response for 06b5a461-abbb-40d8-974b-7dc75dd24804.json saved successfully.
# Response for 06b6dfdc-279c-424b-a093-09fd4af01d3f.json saved successfully.
# Response for 06be8e0c-f009-4c4a-b43a-ceee741553d2.json saved successfully.
# Response for 06cecad5-20b4-4482-8839-7177575150c5.json saved successfully.
# Response for 06d1c401-8ee4-4758-a5ab-54dd306ae014.json saved successfully.
# Response for 06d25c1a-83de-4e7b-a2b6-1c5e1f99c49e.json saved successfully.
# Response for 06d5fca3-6540-4431-9a95-ce5b1ef4ee95.json saved successfully.
# Response for 06dd1292-8782-4eae-bfae-5b66f5c04f79.json saved successfully.
# Response for 06e10cc0-56b0-4725-834e-b6459990216c.json saved successfully.
# Response for 06e4a31e-8f24-4613-8957-cc229048d744.json saved successfully.
# Response for 06e5d984-6c54-49a9-8f55-52e3c135d880.json saved successfully.
# Response for 06f02cdf-6158-40f4-acb4-aaea19f8d533.json saved successfully.
# Response for 070b756d-6257-46e2-8eb5-a0b1feeccaf8.json saved successfully.
# Response for 0711fd8d-e462-4bda-a6e6-a7244656892d.json saved successfully.
# Response for 072e1628-4433-405f-afdb-badf430c652b.json saved successfully.
# Response for 072fc422-5056-42a8-9866-0daea1ebd90e.json saved successfully.
# Response for 073b4184-6dd2-4586-9d0f-a896b3a1b923.json saved successfully.
# Response for 073f084a-4e25-4415-aa26-a2f89a61cc22.json saved successfully.
# Response for 07449ef9-8d75-41be-ad30-924ab46b644e.json saved successfully.
# Response for 074c0478-e10f-458a-9a39-dce58a8102ec.json saved successfully.
# Response for 075227d1-dc7c-45eb-a6da-9b1756728c2b.json saved successfully.
# Response for 07540d24-7939-4bab-b498-17978ab6523c.json saved successfully.
# Response for 075429e3-f22e-4ff5-8849-cb170f833dd8.json saved successfully.
# Response for 076f8cf8-7a99-4bf5-8d29-69fb4627978c.json saved successfully.
# Response for 0770ccde-1868-42e9-9cd3-d8bf16648967.json saved successfully.
# Response for 07786811-81a7-49bf-aad1-2bdb8114475d.json saved successfully.
# Response for 077af874-f964-4dbf-9d15-4615b50efc4a.json saved successfully.
# Response for 077ecfb3-c9dd-4f7c-bf2a-afc3a1d68d97.json saved successfully.
# Response for 078f7ed6-038f-4a1f-88ab-708fd7d18f42.json saved successfully.
# Response for 07909a7f-cae5-4ad8-87a7-fcbffb32eafd.json saved successfully.
# Response for 07973ed7-1826-472c-a6ed-1304356327dd.json saved successfully.
# Response for 079ddb5f-ab25-465e-9221-aee4deb8db1a.json saved successfully.
# Response for 07a7c556-4d18-4439-a9a6-16f916481ca7.json saved successfully.
# Response for 07b94d7c-c06a-4b86-846a-492cc86cd33c.json saved successfully.
# Response for 07bbc2eb-cae5-43ca-b8b4-c0d6054c69db.json saved successfully.
# Response for 07c00c90-c534-4495-9f90-b1eeadf0de3e.json saved successfully.
# Response for 07c73d9c-5937-4e28-82a5-9f5515097cea.json saved successfully.
# Response for 07d8c7b9-5620-4d56-b41a-d5b5fa63a535.json saved successfully.
# Response for 07dc6d7b-7c0a-4590-93e3-433f7567fef4.json saved successfully.
# Response for 07ddcfa0-d494-4aa2-b28f-7ac852c2a187.json saved successfully.
# Response for 07df7224-b4d5-46eb-810a-35a59cb923ac.json saved successfully.
# Response for 07e7b4dd-ee90-4da1-ac1e-c3f5c22f96af.json saved successfully.
# Response for 07ec4367-d2e7-4b2c-890f-7a7c8026b371.json saved successfully.
# Response for 07f0a475-4777-416a-886b-11177b7a68f8.json saved successfully.
# Response for 07fe88bb-d173-4114-930e-16f312b051d5.json saved successfully.
# Response for 0817b693-13eb-4a95-b86a-ad79db09a21b.json saved successfully.
# Response for 082e9312-acd9-4cb6-91cd-43c0fa7578aa.json saved successfully.
# Response for 083cbf0a-d369-45f1-98c9-d36a72b66888.json saved successfully.
# Response for 084982b4-a4cb-40dc-b053-237e9bcd667c.json saved successfully.
# Response for 085349e4-2261-4e70-94b8-ba0b64099dd7.json saved successfully.
# Response for 08571014-35b6-41bc-b025-1ed4a48d72be.json saved successfully.
# Response for 085f08bd-2949-4fdd-a7fb-5ae8a3056b23.json saved successfully.
# Response for 086e5d9b-653d-4dbc-8e8e-0decfcfb44c8.json saved successfully.
# Response for 086fb204-f294-45aa-afbf-ffc47c228047.json saved successfully.
# Response for 089c460c-961d-4cb1-bac1-aaa709457918.json saved successfully.
# Response for 089e95df-1fe1-4cdf-a78e-56085c432613.json saved successfully.
# Response for 08a5df7b-83d0-4e5a-80a4-c9bdb411ee85.json saved successfully.
# Response for 08a6b1b0-734f-4e4f-bf50-3c1e10a2d348.json saved successfully.
# Response for 08ceb454-c303-4e94-ad38-bd66c724a48a.json saved successfully.
# Response for 08d59b46-bf9c-4179-8acd-e38a9c1a8c6e.json saved successfully.
# Response for 08d743f4-3b8a-49e6-919d-2749d67126b0.json saved successfully.
# Response for 08dba95d-8d9d-412b-b10c-ce6fc29dcc9b.json saved successfully.
# Response for 08e1a96d-7532-4f74-a351-c7c65f1be585.json saved successfully.
# Response for 08e64861-7d8e-43bc-ab95-6b9cd90e8b9c.json saved successfully.
# Response for 08e8461e-48a2-4d40-a580-cb88dd078a77.json saved successfully.
# Response for 08f380ff-b8f3-44a9-b781-30131a66dfbb.json saved successfully.
# Response for 08fb8112-b39d-470e-a642-f0ff505c372e.json saved successfully.
# Response for 0906b92c-6721-44f6-8798-bc83cf077c26.json saved successfully.
# Response for 090ba908-0972-4874-9acf-2caf45a022be.json saved successfully.
# Response for 09168d3b-0152-430d-a74a-31fa44ae7e97.json saved successfully.
# Response for 09262be4-667d-4e9e-a15b-c74d90d5f374.json saved successfully.
# Response for 0930f863-3a33-41d4-9f36-24995d188a65.json saved successfully.
# Response for 0936ed8e-709d-416d-be82-b68cb06c3f18.json saved successfully.
# Response for 09423f30-9459-4c3c-a272-e786a9bce9c0.json saved successfully.
# Response for 0942d114-56d4-43ae-906f-3015aba78c4e.json saved successfully.
# Response for 094600ff-0bfc-4e43-bc55-4410012e5ca7.json saved successfully.
# Response for 094ec826-c99f-495c-9ae1-a228e11e0954.json saved successfully.
# Response for 095b0ef7-6024-4887-acc0-08d68ef59f0e.json saved successfully.
# Response for 095fcfe3-03ce-445f-9023-3ba7f82b981a.json saved successfully.
# Response for 096364bc-a667-415c-82da-ce0cc02c6d15.json saved successfully.
# Response for 096a6216-8d44-4083-84ad-aafad9da6d88.json saved successfully.
# Response for 09702f92-7928-4dec-814f-cc56399a9976.json saved successfully.
# Response for 0970b024-8cad-44b1-b386-797af2305d8b.json saved successfully.
# Response for 0970d89f-a4f6-451f-bd64-63e0dbc1bd91.json saved successfully.
# Response for 097fcefe-3edf-4ba2-83bb-5005ccd3a1f4.json saved successfully.
# Response for 09968174-f30e-4457-8caa-e2738a2ee58e.json saved successfully.
# Response for 099ac417-9d80-4498-826a-07e146d161d6.json saved successfully.
# Response for 09a30655-eb42-4eff-a635-20880565bef1.json saved successfully.
# Response for 09abf01e-9870-49ac-ad0a-01632fc9bd0d.json saved successfully.
# Response for 09acd2aa-4136-4436-bf3b-447b5e712f21.json saved successfully.
# Response for 09aee295-a3af-4e57-b621-3a7b28c35770.json saved successfully.
# Response for 09afe017-b934-4b32-aa88-7bfbcb70b7a9.json saved successfully.
# Response for 09b228ad-c18e-4010-a52c-8ffa651c3d52.json saved successfully.
# Response for 09b439d7-eeb6-4751-819e-93e008c7465b.json saved successfully.
# Response for 09be7097-de31-440e-97d8-3c0d4435e3b5.json saved successfully.
# Response for 09bf622b-ba10-4bbf-83aa-e23a03b5ac5d.json saved successfully.
# Response for 09c19d3a-a260-4561-bf7c-289d72180bde.json saved successfully.
# Response for 09d38327-7de9-4180-85b6-8d04b236d2e9.json saved successfully.
# Response for 09ebe123-e407-4b75-91e7-75e43abb8260.json saved successfully.
# Response for 09f5da7f-f9ea-4a55-9372-87a2e4dc9f30.json saved successfully.
# Response for 09f74770-5df3-42f2-b849-06de7c70e21f.json saved successfully.
# Response for 09fe4db6-747e-4e97-8909-5017bd371089.json saved successfully.
# Response for 0a04f077-2073-4c2b-b712-5a107eec2dec.json saved successfully.
# Response for 0a078f61-e68a-4670-aed6-87210eefd46c.json saved successfully.
# Response for 0a123c82-6e98-4786-ad4d-48e46b3c705e.json saved successfully.
# Response for 0a1262ca-f1d8-450f-a61a-3d62f7ea5525.json saved successfully.
# Response for 0a15d21d-05b7-47b7-859b-01de3aa23628.json saved successfully.
# Response for 0a19b75f-05dc-43bb-b7d5-7675c4b66ea6.json saved successfully.
# Response for 0a1fe1ed-bc4e-4696-b85a-995ed49b2e45.json saved successfully.
# Response for 0a323501-a942-4e11-a25f-f59eefb8e19a.json saved successfully.
# Response for 0a356315-7f86-4fce-aeb9-6aa92dfbdf5a.json saved successfully.
# Response for 0a3a9cbf-e787-4fe5-942b-6f9ac214734f.json saved successfully.
# Response for 0a486f52-920d-46a7-878b-268bb757e9cb.json saved successfully.
# Response for 0a4cce32-c3f1-458a-a2dc-81b319abbb37.json saved successfully.
# Response for 0a508ac0-09e7-465d-bd9e-86e230c955fc.json saved successfully.
# Response for 0a540302-8ebb-4604-8725-10770e805b31.json saved successfully.
# Response for 0a543340-8816-4ab8-a5e3-3f2483a2b84e.json saved successfully.
# Response for 0a5b64ae-834f-465f-aa3a-ac17d5c07dfe.json saved successfully.
# Response for 0a5f75fc-464a-4bb3-8688-cd0eedecf703.json saved successfully.
# Response for 0a6e8624-6360-4730-a188-15893ac1bebd.json saved successfully.
# Response for 0a7040f4-7473-4ff1-abc7-f2f4cf57b044.json saved successfully.
# Response for 0a7222aa-4100-43a9-b494-cc1089a98f10.json saved successfully.
# Response for 0a755224-7747-4703-916b-d351e58f1662.json saved successfully.
# Response for 0a855d19-6a60-4954-9588-3688ea8252a3.json saved successfully.
# Response for 0a89a32d-ce3d-4869-8cc7-2aca431d78f5.json saved successfully.
# Response for 0a8c20d6-c96d-45d9-8174-2c3c59ac04b0.json saved successfully.
# Response for 0a8f7372-1ce7-4b55-8391-164784be2d50.json saved successfully.
# Response for 0aa7c4ba-40ef-44ef-b21f-6a0e5f29a23b.json saved successfully.
# Response for 0aaa7e67-6d53-4406-879f-0bfb3247fcb9.json saved successfully.
# Response for 0aab31f7-1c44-4b0d-88e1-1700b61baa21.json saved successfully.
# Response for 0aaccc98-c15a-4acf-a2f7-4b7e467855bf.json saved successfully.
# Response for 0acc3fb5-d5d1-4a03-9918-222dec379528.json saved successfully.
# Response for 0ad12c54-cf62-4b5b-817f-cef846c6868e.json saved successfully.
# Response for 0adf795f-cdb8-4723-8434-5ed4e1467c85.json saved successfully.
# Response for 0aec1e83-8c97-436c-b851-cf1e56e1c661.json saved successfully.
# Response for 0af9db5b-f344-4c80-83a1-35abe432c248.json saved successfully.
# Response for 0afa327d-e8f7-454e-9018-7468c2771593.json saved successfully.
# Response for 0afa79c8-6178-47b6-93e1-23c589c422a4.json saved successfully.
# Response for 0afb7e42-255a-48e3-8a9d-a194ebdfd94f.json saved successfully.
# Response for 0afdd6b0-7ff1-4579-87bf-1fd96eb3e32e.json saved successfully.
# Response for 0b0f9ac1-35fc-44f0-8914-2d3b4be591f7.json saved successfully.
# Response for 0b1a62f2-1dda-485b-811b-99f55dd6d3c6.json saved successfully.
# Response for 0b2a456d-e19a-4b4d-b346-08346cec231a.json saved successfully.
# Response for 0b31b33b-f819-46cd-8418-53ed6939e280.json saved successfully.
# Response for 0b4a1707-2c9f-4265-85f4-79fca14b8e6a.json saved successfully.
# Response for 0b4da296-c890-4046-91e4-09b39c8cd6f2.json saved successfully.
# Response for 0b562c64-b204-4e2b-bb85-b6de3f5f0167.json saved successfully.
# Response for 0b56e01d-f18c-41be-ade6-19e2ec134628.json saved successfully.
# Response for 0b5cf932-8ad2-4aed-b621-1060215c6299.json saved successfully.
# Response for 0b5d8efd-a958-4eaa-b155-bf98e25e47c0.json saved successfully.
# Response for 0b66e357-bff2-4da4-8566-67aae05a7de7.json saved successfully.
# Response for 0b6c7019-8213-4de1-b05d-c260cfb9f0d5.json saved successfully.
# Response for 0b6e35cd-651e-495b-bbbb-76be5eb3d63d.json saved successfully.
# Response for 0b72bcce-96f3-46d2-afc4-8cf478eb3a92.json saved successfully.
# Response for 0b835810-6193-4046-a7ba-25c783d94c05.json saved successfully.
# Response for 0b989224-85e6-4308-a5dd-d1fa7ba5222a.json saved successfully.
# Response for 0ba6be89-a131-4b1e-9dc0-59852e513779.json saved successfully.
# Response for 0ba6e503-9de5-4e25-924d-2c6781c29231.json saved successfully.
# Response for 0bb48dd6-1a11-40c1-8ccd-81a7b1ba5441.json saved successfully.
# Response for 0bb7259d-b2d4-4406-aecf-4b8873d0ee21.json saved successfully.
# Response for 0bbe9739-38f6-42ca-b02d-7b4192ed2137.json saved successfully.
# Response for 0bbfb2ba-4d0f-4e87-baa4-de7e31b019bc.json saved successfully.
# Response for 0bbfc381-58b2-4698-ad16-1d3fe7a53d4b.json saved successfully.
# Response for 0bc46047-fd67-4036-aed7-d1aa7ac64df1.json saved successfully.
# Response for 0bc50db1-45a9-4e4a-af9a-608803f732f6.json saved successfully.
# Response for 0bd54942-05d0-4c17-9402-98d63e692067.json saved successfully.
# Response for 0bd7dedf-f9c6-45b4-aa99-7f233e8682c9.json saved successfully.
# Response for 0bd8a033-edba-47ea-b66c-7f5e1c025eed.json saved successfully.
# Response for 0be05751-317e-4595-abb5-858746889b15.json saved successfully.
# Response for 0bee4495-170a-45a6-b042-11a61a5d4f56.json saved successfully.
# Response for 0bf43917-730d-43e3-97b1-4ea99dc40eab.json saved successfully.
# Response for 0bf4f81f-f6da-48b6-ae64-9fbd7209093a.json saved successfully.
# Response for 0bfb7980-f6c0-4e0c-956a-136d07ef8558.json saved successfully.
# Response for 0c03f2fc-8f39-4028-927c-b63486facee9.json saved successfully.
# Response for 0c0471a0-2652-4327-9ea3-073f0ac2d16b.json saved successfully.
# Response for 0c075b43-a3a8-43bd-ac2f-3906020b5d27.json saved successfully.
# Response for 0c08677a-6bcc-4f6f-99ec-698332e06d40.json saved successfully.
# Response for 0c0933b6-f316-485a-a189-72d06482b940.json saved successfully.
# Response for 0c0bf552-1b34-4bd4-b407-469f6138fb99.json saved successfully.
# Response for 0c1dc9d8-e86a-446f-94f1-d9db503c4389.json saved successfully.
# Response for 0c2ea7da-a07f-4b72-bb84-5711e17807e1.json saved successfully.
# Response for 0c32c7d7-d792-4d20-b10e-196b698c780a.json saved successfully.
# Response for 0c33f795-9f2c-4d14-9f3e-7ef57a821c5c.json saved successfully.
# Response for 0c3cc9b6-19ca-4b06-8692-67ad276210eb.json saved successfully.
# Response for 0c4e4d69-0adf-48c5-960f-75847e76e668.json saved successfully.
# Response for 0c6108ba-fdb6-4d0e-bb2b-001335bb2837.json saved successfully.
# Response for 0c69b421-bbc6-47be-be9e-afcf4a01f7a3.json saved successfully.
# Response for 0c7fe808-c13f-4b9b-8375-036e5bb313ba.json saved successfully.
# Response for 0c83465a-fb68-405e-b3f0-5a7f89845ded.json saved successfully.
# Response for 0c861b16-b7be-4f72-ac59-1beb37d74bd9.json saved successfully.
# Response for 0c8d86ed-3deb-43b3-becf-01d82cc9f8b9.json saved successfully.
# Response for 0c95edd7-0b3a-46e4-b638-6cadd2a7be4d.json saved successfully.
# Response for 0c974111-dc09-4fd6-8c8d-7ddca2518043.json saved successfully.
# Response for 0cbb1c23-9ff4-4f8b-9978-6e72cfcfc0d4.json saved successfully.
# Response for 0cbcaedd-8c8e-4b39-ac4f-e02e435e1e8c.json saved successfully.
# Response for 0cc22262-3484-4c91-b466-2884185828de.json saved successfully.
# Response for 0cc48306-db84-4595-9042-377f6e9f69f0.json saved successfully.
# Response for 0ccd0291-53ce-4774-8f55-1f449b745d4d.json saved successfully.
# Response for 0ce0844a-a653-47a0-8b3f-2aa1b697032b.json saved successfully.
# Response for 0ce14de7-bc40-4ea1-b341-54c791b3f853.json saved successfully.
# Response for 0ce18a61-7ee7-44d1-9c87-291377879a82.json saved successfully.
# Response for 0ceec7e9-cb9d-4498-9537-6f88de60f70d.json saved successfully.
# Response for 0cf217a7-314b-48de-b05f-7182336bb3f6.json saved successfully.
# Response for 0cfecf89-767b-415d-8086-bf7825e5c5a0.json saved successfully.
# Response for 0d0931be-3df7-40b3-825f-52b66d4f5ad2.json saved successfully.
# Response for 0d12e564-b677-44c1-95ba-23a1b44efb40.json saved successfully.
# Response for 0d162d4d-c042-4211-861c-c28d497b562b.json saved successfully.
# Response for 0d197619-28e9-4ca1-bf35-5b3ab1a27d57.json saved successfully.
# Response for 0d23bf0e-bed2-4bb6-afbe-9b5edc47dba1.json saved successfully.
# Response for 0d31b6a7-95c5-4f29-a807-2cdf01a7c6e7.json saved successfully.
# Response for 0d3db233-fff6-4735-af4b-02b8592c397a.json saved successfully.
# Response for 0d41890a-e1b1-4605-9e92-1cb7c4ade70c.json saved successfully.
# Response for 0d487dee-0ccc-4907-915e-b211731a1bf5.json saved successfully.
# Response for 0d7bf2ca-ea8b-4484-9eb3-d95eb613f593.json saved successfully.
# Response for 0d813a2b-4ca7-44f5-92a6-36435846f405.json saved successfully.
# Response for 0d90c3ab-cc0d-4bc3-ae21-5a3bd724fa19.json saved successfully.
# Response for 0d944771-711e-4762-8b8a-cff5085e84b2.json saved successfully.
# Response for 0d959954-5016-45ea-b2bd-0578aff8a466.json saved successfully.
# Response for 0d969dc9-ff6e-4193-9540-33fe696d4608.json saved successfully.
# Response for 0d9c66cb-3dc2-46cd-906b-483908b002e5.json saved successfully.
# Response for 0dace130-774e-4738-8752-2ce624d2ab33.json saved successfully.
# Response for 0dbc094a-11fb-4f1a-98b9-35bae761d68f.json saved successfully.
# Response for 0dce9595-3009-4760-a7a0-720c74b3c840.json saved successfully.
# Response for 0dd6e179-19eb-427c-a5d7-1ff582aa2f6f.json saved successfully.
# Response for 0dd89922-4c1f-4851-93e5-d8edca358866.json saved successfully.
# Response for 0dd8ed08-6b3e-4a46-bd1c-3a311bfa666c.json saved successfully.
# Response for 0ddcd86f-6d39-4266-836b-9e202577b442.json saved successfully.
# Response for 0de21ade-8d55-4805-9901-55fef28c7b0c.json saved successfully.
# Response for 0deed689-daa8-408f-9917-f94f7c5322ec.json saved successfully.
# Response for 0df123b6-3e0f-4769-8eb7-293e771efcd5.json saved successfully.
# Response for 0dfaa287-9b62-4085-a73b-1902de4680a1.json saved successfully.
# Response for 0dfb5cf4-6dfc-4ef6-8dd9-7d68dcc1fd62.json saved successfully.
# Response for 0e042816-6f27-49f5-8f25-b0edc74e036e.json saved successfully.
# Response for 0e06212d-7ef6-4ef6-b719-810b886453c0.json saved successfully.
# Response for 0e17f68c-ef7e-4660-846b-1db438b219a8.json saved successfully.
# Response for 0e18d9a5-4683-46fa-b313-3ba6d3e5216f.json saved successfully.
# Response for 0e2fb754-2fc8-4340-8012-3f1fb40a010c.json saved successfully.
# Response for 0e3aebe8-8007-4e5b-9ac2-f61a57e53515.json saved successfully.
# Response for 0e40f22e-d68d-4541-a298-d91eead74586.json saved successfully.
# Response for 0e46c107-7056-4d99-9484-a2b9545db2e6.json saved successfully.
# Response for 0e5550cd-6395-4607-91e1-338c949965f0.json saved successfully.
# Response for 0e6207cf-d795-41bd-9657-a23ff8f8871d.json saved successfully.
# Response for 0e6be5cf-1dfa-49cc-a146-f63631cc4319.json saved successfully.
# Response for 0e7e342c-fead-41fd-b091-809fe0d9a423.json saved successfully.
# Response for 0e8a1b8e-e59d-422e-8cc4-42dcad1404e4.json saved successfully.
# Response for 0e8aa4e1-5499-4d5c-900f-5c7844791980.json saved successfully.
# Response for 0e8baece-a52c-4597-82a2-45e9e3c3c06b.json saved successfully.
# Response for 0e996676-5554-4cbc-a6e1-acc436877830.json saved successfully.
# Response for 0e9c7117-6076-488d-8b8a-5405377e8a4e.json saved successfully.
# Response for 0ea818e0-6357-4258-8c56-2d3ba8b3e30a.json saved successfully.
# Response for 0eb49ef2-6f52-406b-926b-d66b06797add.json saved successfully.
# Response for 0ebf269a-0ebe-4287-a247-15b669a41c09.json saved successfully.
# Response for 0ed4eca6-e8d9-46e5-a414-3d0fead5d300.json saved successfully.
# Response for 0ed84206-8dbe-4b02-9852-3a80f43eacd4.json saved successfully.
# Response for 0edf4730-9a99-418f-9911-a67722b582de.json saved successfully.
# Response for 0ee65d42-1620-442a-af5a-c74ab95e4f08.json saved successfully.
# Response for 0eed9349-4430-45b6-955f-09d6525f24b8.json saved successfully.
# Response for 0f017cf4-44ae-4ea1-a0ac-8331f1f8097d.json saved successfully.
# Response for 0f0326ea-772d-4b0b-b203-3ee615a7eb1e.json saved successfully.
# Response for 0f03e421-13f3-4af3-93f3-94c5b05ce51f.json saved successfully.
# Response for 0f27271b-209a-4157-ab34-5128b9c387cd.json saved successfully.
# Response for 0f293369-4d6f-4a3d-afa5-31f1f477842a.json saved successfully.
# Response for 0f2aa9c3-ea95-4d53-b3cb-9f5159846b4d.json saved successfully.
# Response for 0f3017ab-69f5-4ae0-9da3-cf581a41b812.json saved successfully.
# Response for 0f34a3b2-86de-4fda-9948-7b649e956989.json saved successfully.
# Response for 0f4096b6-65ce-45b1-9aa2-bd3e870ed559.json saved successfully.
# Response for 0f4287e0-ff62-461f-b389-94128fcdca02.json saved successfully.
# Response for 0f43c7f3-c3c2-4e18-81c6-f52a3a9151bc.json saved successfully.
# Response for 0f4e2cd9-41c4-4e10-9bb8-53a93bd8592f.json saved successfully.
# Response for 0f514c55-a427-42ae-8c11-5c6bc07a84ab.json saved successfully.
# Response for 0f57abaf-a392-48c9-8e78-849ba59de4cc.json saved successfully.
# Response for 0f5e7299-1d47-48c9-bf70-9cb008fdb375.json saved successfully.
# Response for 0f5fbd47-fc77-4c0b-8022-fb15cd9d039a.json saved successfully.
# Response for 0f72bc44-fcd1-4fa4-86cd-26d556b8188f.json saved successfully.
# Response for 0f7dd602-633a-4100-a006-1b57687e961f.json saved successfully.
# Response for 0f88229d-4858-4193-9761-37406e132c86.json saved successfully.
# Response for 0f92be51-91e6-4ba1-9ce9-04b2fb6a92d7.json saved successfully.
# Response for 0f9a7ec9-8199-4277-a3ff-164acc189dcb.json saved successfully.
# Response for 0fa02f3d-39a3-4e96-81b1-421a57e1f2e4.json saved successfully.
# Response for 0fb4acfa-5c30-4acf-9b1f-d1f9c6b5e257.json saved successfully.
# Response for 0fb672b8-01c8-486c-b794-afa2ecddd422.json saved successfully.
# Response for 0fb788f4-9e55-4ab8-8faa-606a1fed1ae1.json saved successfully.
# Response for 0fbf198b-12db-4b1f-9b95-46f8a55ed31c.json saved successfully.
# Response for 0fc57826-d6ce-4fcd-b4c8-6253fa0c7890.json saved successfully.
# Response for 0fefec08-a491-481e-9dde-35b08b5f32a5.json saved successfully.
# Response for 1008c419-f83e-4e51-ba75-5a44c3d0f23f.json saved successfully.
# Response for 100e9318-23e2-47e4-a007-bcb5c474b4c3.json saved successfully.
# Response for 101df3d4-8e51-47c0-8700-daf14d5c1069.json saved successfully.
# Response for 1037ab83-fcca-4acd-9f32-6588d4b2e7c2.json saved successfully.
# Response for 10580290-20ec-4481-a3fb-f21e5b1de203.json saved successfully.
# Response for 105bab9d-74af-4b40-869b-16e3f0e024ff.json saved successfully.
# Response for 1061df63-2e80-4900-8426-178927798fbf.json saved successfully.
# Response for 1076a7eb-c16d-4e6a-94f3-35a952888fbd.json saved successfully.
# Response for 10886599-c842-426a-9924-42908461576f.json saved successfully.
# Response for 108875fc-5e8e-456d-871c-4ddfdf01371a.json saved successfully.
# Response for 10977d89-dd95-4e7b-b316-89479ecb974b.json saved successfully.
# Response for 10a81797-c345-4a97-aa80-8f98205b43ce.json saved successfully.
# Response for 10a970d3-4b54-4add-86e3-8f4b8ffec9a7.json saved successfully.
# Response for 10b4e59d-e364-4854-b60d-f42886ad80c1.json saved successfully.
# Response for 10b8f973-5a2b-4c23-a4a0-15643134b0f4.json saved successfully.
# Response for 10c1391b-7062-4dbd-905c-f80d6bb03e1f.json saved successfully.
# Response for 10c67d7b-b425-4106-ac3a-8591f9828af8.json saved successfully.
# Response for 10c6bdbd-946a-4d68-a021-cefa5adc355d.json saved successfully.
# Response for 10c6e604-cd68-452f-9e08-4ec40e420c17.json saved successfully.
# Response for 10c9291a-c485-4443-a9b0-7d5ac28001f3.json saved successfully.
# Response for 10cba72c-f1b6-40c3-8d15-0dea90b37ad9.json saved successfully.
# Response for 10d6c3ef-8391-47dd-806d-00e8be38a460.json saved successfully.
# Response for 10d824ec-1a6b-4522-a82a-20e24f2d3e3a.json saved successfully.
# Response for 10dbbffd-ff63-47b6-89d4-bbf23c469f20.json saved successfully.
# Response for 10ed7e47-60da-4b5c-98bd-70e24fd955e7.json saved successfully.
# Response for 10f2c146-7987-40a6-b730-5079b3cd4254.json saved successfully.
# Response for 10f56bc1-7aed-40a5-8c24-d2d7289a9282.json saved successfully.
# Response for 110ce344-a53d-4932-9d1b-ce0b30f2b913.json saved successfully.
# Response for 110ede6b-ea20-4221-b171-8d3c48b9be96.json saved successfully.
# Response for 11134cbd-706e-4fb4-bcae-77ef8c2befcf.json saved successfully.
# Response for 11140110-13dd-4a31-bb86-648a835b1780.json saved successfully.
# Response for 111b72f1-b5f7-417e-8bd9-571ce95f8b23.json saved successfully.
# Response for 113b0ab2-97c5-491e-900e-c4f062830734.json saved successfully.
# Response for 115292ad-e934-43e1-aba7-0a794b5dc6b8.json saved successfully.
# Response for 1152b1f0-da4b-4713-8833-611b61b8dbdc.json saved successfully.
# Response for 11586313-2187-4c4c-a462-1f62be0c0724.json saved successfully.
# Response for 1160fc7f-c5b5-4ca1-9fa5-f26333bc5c2d.json saved successfully.
# Response for 116b759c-3d9d-4e93-ae6f-3ad64fab4172.json saved successfully.
# Response for 1172e84f-6260-4573-98cf-d44e4109273b.json saved successfully.
# Response for 117491ce-da40-41d7-911c-7973bed81e0c.json saved successfully.
# Response for 1181830b-038e-4b86-b3f2-ec321de12773.json saved successfully.
# Response for 11840c8c-a702-4111-be8e-18f0d6c9982e.json saved successfully.
# Response for 1186b4f1-e474-4b99-9549-4bae9a74e6c6.json saved successfully.
# Response for 1192977f-b1f1-4620-a389-bde2c04b7231.json saved successfully.
# Response for 119494c2-2c9e-4820-9128-7ae748748f13.json saved successfully.
# Response for 119fea8b-b6ae-49f9-847b-995c1f159b70.json saved successfully.
# Response for 11ac38aa-a364-41b5-be59-03541ea6d469.json saved successfully.
# Response for 11b2a58c-2b42-4cbf-86a5-f8896df05c7c.json saved successfully.
# Response for 11b42ddc-b28f-4cbf-ada4-d29d240e7ee0.json saved successfully.
# Response for 11b5fd7b-d811-4f3e-99d2-fd052f2826f5.json saved successfully.
# Response for 11b7ac1f-0105-4de4-ae9b-485582028cb3.json saved successfully.
# Response for 11bef7b0-4b55-45c7-b8d3-894d9c154adf.json saved successfully.
# Response for 11c01bd2-69ea-45f2-99e1-db3e773b3266.json saved successfully.
# Response for 11c436f3-7ebb-489d-bfb7-ea27c8181301.json saved successfully.
# Response for 11c554a4-37e1-42ca-8c7a-b500099afb96.json saved successfully.
# Response for 11cd408c-157a-43f2-8375-d402e0bdabeb.json saved successfully.
# Response for 11d67982-f045-4a3f-a641-af74562375b1.json saved successfully.
# Response for 11e18dbd-b80a-4a6a-ab76-bfcdba8c4277.json saved successfully.
# Response for 11f299de-1cfd-48d5-89f8-6ef2f99d8d7a.json saved successfully.
# Response for 11fa656b-051b-4fd1-bc2e-44e7c3143194.json saved successfully.
# Response for 11fa8a35-b333-4079-84d4-084dcb6390f9.json saved successfully.
# Response for 11fe6699-4e73-47ec-84da-212596acb6bc.json saved successfully.
# Response for 120669a1-aba6-4392-933a-db5f7fddc4f1.json saved successfully.
# Response for 120951f3-2ea7-4d80-bedf-b1869351b726.json saved successfully.
# Response for 121ff68c-3629-4a5c-b1cc-8833ab3725ab.json saved successfully.
# Response for 1223ba26-5a9e-4c7b-b360-4599dace0e40.json saved successfully.
# Response for 122f4a53-7725-492d-afc1-f1c4fb6fa9cb.json saved successfully.
# Response for 12339cea-91d6-45d6-975d-3c9ef4060053.json saved successfully.
# Response for 1248cc31-565d-4dc8-96e0-91452fbb6e20.json saved successfully.
# Response for 12490495-ff63-45ad-b625-010acfbd2d98.json saved successfully.
# Response for 124bda73-86c4-49a3-9606-752140836439.json saved successfully.
# Response for 1258bbd5-4a2e-4bee-845d-f0b826dfeb62.json saved successfully.
# Response for 1259a7d7-fdfb-46ef-a325-3b718ce2aa3b.json saved successfully.
# Response for 12615871-113a-41cc-88e6-ae0166ad765d.json saved successfully.
# Response for 1261cfeb-bf50-4381-a923-23966f581cc9.json saved successfully.
# Response for 1264b2a1-ba14-46a0-9be1-02ca0b5bc3ab.json saved successfully.
# Response for 12650f34-62da-48a8-9bc4-d62831bcf3d8.json saved successfully.
# Response for 126fb019-e441-40d7-94a6-8e4d1bca0f71.json saved successfully.
# Response for 128baa1a-44b0-4dc7-b812-77913c54556a.json saved successfully.
# Response for 1298c390-4721-403b-b926-7d56146ddd44.json saved successfully.
# Response for 129e71c1-0d19-4c5f-9397-eb8b1c83d43d.json saved successfully.
# Response for 12adb5f9-dc5a-4374-91c9-802e0128f5c7.json saved successfully.
# Response for 12ba2b26-afb8-4e83-a685-215bfada6d6a.json saved successfully.
# Response for 12bca639-adfe-4d73-8a7f-33f3641b5dae.json saved successfully.
# Response for 12bdabb9-6b68-4330-9b08-e47d6750e2c3.json saved successfully.
# Response for 12c6e672-85f5-4994-b66f-0a9baa63f436.json saved successfully.
# Response for 12d75604-51e4-4a2d-a4dd-1131d8ce6564.json saved successfully.
# Response for 12e3c85a-e02b-47b8-9e33-5ca4f5a2a5b2.json saved successfully.
# Response for 12e78224-d106-4123-8511-88c1a7dff42d.json saved successfully.
# Response for 12e7fc2a-0683-4177-b961-17f644e4ef25.json saved successfully.
# Response for 12e9a5ee-eb28-48e2-be75-445b37e4e4ec.json saved successfully.
# Response for 12f314f2-3fa7-4b36-9e24-5b0595fe29fc.json saved successfully.
# Response for 12f69170-cf20-4eba-9bf6-67e11d56ac69.json saved successfully.
# Response for 12f98d67-574c-4639-99f3-66755ef09147.json saved successfully.
# Response for 12ff188c-18bb-435c-aa55-9140337565d8.json saved successfully.
# Response for 1308f882-cd9a-4b6c-a03d-6e4667ed2346.json saved successfully.
# Response for 1309b177-73ef-419a-91bf-d4be735380c7.json saved successfully.
# Response for 130b684a-fab5-42a7-9075-c72c6bc6da9f.json saved successfully.
# Response for 13133f7d-8225-472a-8346-affa8f9b05a6.json saved successfully.
# Response for 134275c8-90f8-4840-b999-bef69f20daff.json saved successfully.
# Response for 13438207-b911-4062-a6da-dacd2d7321fe.json saved successfully.
# Response for 13513731-1be3-47e8-b17e-66e5e686e623.json saved successfully.
# Response for 135e531c-67ca-48f7-a302-f31ff52077a9.json saved successfully.
# Response for 1368a40f-609d-4f9b-8a5d-e3fc90701c93.json saved successfully.
# Response for 13690a0d-3eca-43e3-84e3-197f7ac70731.json saved successfully.
# Response for 136a6939-bb12-4847-9e07-0908b53b05fd.json saved successfully.
# Response for 136ba179-4f8c-4dc6-a740-ad9aa0115fa8.json saved successfully.
# Response for 136c5101-3571-44b2-834f-cb5bb5912b9b.json saved successfully.
# Response for 13713bbb-1799-4249-8519-2a2eda78423e.json saved successfully.
# Response for 1387c958-fbed-4172-9d7e-7aca293a8654.json saved successfully.
# Response for 1390afcb-cc7c-4db8-b0b3-13799225fd48.json saved successfully.
# Response for 139bf234-9454-404b-8cf6-ab1c2245ffab.json saved successfully.
# Response for 139ebe75-9c82-422e-95da-cedf820691ab.json saved successfully.
# Response for 13b15088-8402-420a-92d8-80ec75274ccb.json saved successfully.
# Response for 13b4dd54-08cb-4bf3-9c21-f138fef244b4.json saved successfully.
# Response for 13bd1e21-e4a5-458d-bacd-3ccbcc881237.json saved successfully.
# Response for 13c2dbdc-6be2-481f-aecf-e8cd34f4aa41.json saved successfully.
# Response for 13c57805-41df-4fde-952d-bbaf069fdd96.json saved successfully.
# Response for 13d2dffa-408e-452b-9d03-1327c15f5b1f.json saved successfully.
# Response for 13d73966-5032-4770-be18-af4ff0efc385.json saved successfully.
# Response for 13d84767-6738-4384-a788-237614865f80.json saved successfully.
# Response for 13de3104-c89b-4670-8b99-78bd9f115d20.json saved successfully.
# Response for 1411723d-d1af-4c1d-a32e-6ba324c8abf7.json saved successfully.
# Response for 143297a3-b1a3-4cf8-a2cb-b9e1da2ed032.json saved successfully.
# Response for 1433ebf0-453c-4fb1-ab65-08025c6b0f35.json saved successfully.
# Response for 1440f984-b1da-4689-8d8f-17de6b4122eb.json saved successfully.
# Response for 1446e06f-8805-42b6-8487-0b25f2600fe2.json saved successfully.
# Response for 144d0e36-9dbb-4d3e-9eba-865a7e4ae7a2.json saved successfully.
# Response for 1458582f-100a-4257-8c51-f9f75cde108e.json saved successfully.
# Response for 145a3edc-38d5-44eb-8dcb-e0dfac610a6f.json saved successfully.
# Response for 146462dc-869f-4828-9d9a-a9bf2f9c37b1.json saved successfully.
# Response for 146af11b-47ba-42dd-82ac-0313c44fdc06.json saved successfully.
# Response for 148f90fa-adc0-44d7-a5e4-529e42bbf0f8.json saved successfully.
# Response for 1497bc07-e91c-4d31-b882-b90396e90f01.json saved successfully.
# Response for 1498832a-3c2b-4d55-9ab6-4cff50e8651e.json saved successfully.
# Response for 14a2886e-efe7-43ec-9ac2-b9bd5ed66f00.json saved successfully.
# Response for 14ae4728-5782-4e29-93f3-9e7580f5c2d8.json saved successfully.
# Response for 14bb37a4-8be3-41f5-adfa-dfccc4590713.json saved successfully.
# Response for 14be5237-32df-41cd-968d-c36b0a147f97.json saved successfully.
# Response for 14da807a-9e6e-44c9-a341-b68ecd93d5ea.json saved successfully.
# Response for 14e1fac7-9111-44f1-9e09-91e0174fd72f.json saved successfully.
# Response for 14eeafa8-dfd4-4bbf-af05-e20449da6089.json saved successfully.
# Response for 14f9ebff-f4a0-462e-a56c-4db83904b0cc.json saved successfully.
# Response for 14fbba9f-755e-4648-92a7-31ff698e967e.json saved successfully.
# Response for 1506335e-d5c1-4a86-81d9-c32982cea03a.json saved successfully.
# Response for 1510781a-c88d-45e5-9fc7-04d019968a26.json saved successfully.
# Response for 152f68c8-4b52-41b8-8b33-3971155fca62.json saved successfully.
# Response for 15462447-7837-49e9-922c-86c6eb72874d.json saved successfully.
# Response for 15577355-f28a-4a0b-8c73-19067c378028.json saved successfully.
# Response for 155d656d-0893-4ea2-9b56-2d47d2a31fe2.json saved successfully.
# Response for 1564c680-f9f6-4073-8554-0c1389c18bc7.json saved successfully.
# Response for 15659338-d18c-4e7f-931a-748efeaaf581.json saved successfully.
# Response for 156d3f0a-39ca-4816-99f3-d70c99dbff0b.json saved successfully.
# Response for 157365bf-5f0a-42dd-aae4-70355dad5464.json saved successfully.
# Response for 157a29bc-2ebd-4e37-b58e-15259e15b504.json saved successfully.
# Response for 158514e2-14b7-49ed-8479-fe9bca7998eb.json saved successfully.
# Response for 15b65288-79c2-4adf-a469-09d0d3b87351.json saved successfully.
# Response for 15b7df1a-73b3-4111-8151-72a369b03b3d.json saved successfully.
# Response for 15bd0cd0-48ee-4c4f-a30d-d7339a2259b7.json saved successfully.
# Response for 15c175e9-c420-4862-a62f-81c3a38faaf3.json saved successfully.
# Response for 15c84370-5723-4418-ab0e-6dcca3d92e73.json saved successfully.
# Response for 15c8da25-18a3-4fca-9564-1ee5a0ed4a89.json saved successfully.
# Response for 15c93d12-ea71-45c2-8934-dcd36abcb868.json saved successfully.
# Response for 15cdbdbe-16d9-47b9-a405-9986f282aceb.json saved successfully.
# Response for 15d9fece-0e74-4883-b686-8291f76e03f5.json saved successfully.
# Response for 15dcd0db-374f-43f6-af47-9307057e0f5c.json saved successfully.
# Response for 15e0cdb0-b694-4aaa-bb88-df24591511ba.json saved successfully.
# Response for 15f6911d-4990-4422-92ce-ea3dc97838dc.json saved successfully.
# ...
# Response for f7ad0585-ba3f-48ac-9b17-7beb04494dae.json saved successfully.
# Response for f7b57f40-0112-4600-bad3-a6a368975be5.json saved successfully.
# Response for f7c9290f-56c2-4c2c-929f-39eb5ee381d6.json saved successfully.
# Response for f7d0c2de-75fd-4a6b-9813-f6d7d07662bd.json saved successfully.
# Response for f7d92832-7085-4214-be8b-9d7fd95080d5.json saved successfully.
# Response for f7dd10e2-dc68-4b2b-9863-bafbe8defe99.json saved successfully.
# Response for f7f0c9dd-8269-4f2c-a1a5-aae3dc9b6aeb.json saved successfully.
# Response for f7f663a1-a694-43d9-9619-6e9ee1c9f818.json saved successfully.
# Response for f7fb8517-f591-4280-81d9-91fb3f3da7a1.json saved successfully.
# Response for f807fc3f-6b63-40b6-a3ee-f237d1a80f2b.json saved successfully.
# Response for f8188f13-9132-4172-b3c3-9702c510bd59.json saved successfully.
# Response for f8230805-d025-493c-b320-e6cbef4c15c5.json saved successfully.
# Response for f824dbd3-a3d9-4878-8af0-41f44f3e5081.json saved successfully.
# Response for f82d9abf-2abd-414c-a453-ec59e8f4d7a9.json saved successfully.
# Response for f8323a23-5308-476b-837d-7be23b88c033.json saved successfully.
# Response for f833b4e0-2544-420c-9d09-151fb4c06ba7.json saved successfully.
# Response for f83968bd-bd44-4e78-a56a-9ccb68525b90.json saved successfully.
# Response for f847ca94-0a29-4d3b-8b5a-20aea126d00f.json saved successfully.
# Response for f84b383a-7ea9-4747-96e6-5174b7bbefe5.json saved successfully.
# Response for f84d3c4b-8c93-45cf-8fc1-68f435c90cdb.json saved successfully.
# Response for f8526dfc-441a-427e-a290-34f5a254484b.json saved successfully.
# Response for f8536c87-43c6-4a27-b527-28e9c5d03bdd.json saved successfully.
# Response for f856367d-740b-4ce3-ab85-37b030058960.json saved successfully.
# Response for f86534d5-88e2-4bb9-a77a-cd87d744b89b.json saved successfully.
# Response for f8742410-6ab5-47a2-bdcd-0e740cf856ff.json saved successfully.
# Response for f87552ae-8571-413f-9a54-e1f8b0b29ad9.json saved successfully.
# Response for f879b7b7-15ac-49d7-ae73-154103090a1d.json saved successfully.
# Response for f87ba7af-9225-4f70-9e1d-4691e5e7fba1.json saved successfully.
# Response for f87d53a4-e6b8-4c30-b2a2-a50923625189.json saved successfully.
# Response for f882387b-e5c9-4ced-9894-66082c0e1d24.json saved successfully.
# Response for f884fd14-7d72-476f-98d7-ec563b651f61.json saved successfully.
# Response for f88aa9f3-3a71-4b5b-a416-a961d571cede.json saved successfully.
# Response for f8926146-1fe1-4a1c-a088-4ba5cae75a72.json saved successfully.
# Response for f8a8486a-ea43-474f-8b82-f40d7e5117b5.json saved successfully.
# Response for f8b05ee7-07b8-4d8e-9b82-9914244af9c0.json saved successfully.
# Response for f8bfe221-2ccd-4b8b-89f9-7c7ab2b0679c.json saved successfully.
# Response for f8c26d1e-9d6b-47ec-aab6-b82277691875.json saved successfully.
# Response for f8d607fd-da91-4ce1-b898-6cd2d6c3b21d.json saved successfully.
# Response for f8d67462-3f2e-4a74-8fae-643deebd0552.json saved successfully.
# Response for f8e20462-e30c-4133-9cfc-8163d7ddc4e6.json saved successfully.
# Response for f8eebe34-6b11-4789-9193-efeb9557ff8e.json saved successfully.
# Response for f8f6845a-bede-4e97-8aa1-9d98f982bca5.json saved successfully.
# Response for f911024c-2728-4033-895c-3e5e57da150d.json saved successfully.
# Response for f913433f-ffcd-4afc-9e90-6b7c642317bd.json saved successfully.
# Response for f914d0eb-46ee-473d-a27a-ae06601bd3f6.json saved successfully.
# Response for f923b560-9472-45f4-838a-f1a29e125c5b.json saved successfully.
# Response for f92ae048-4df3-4e5d-8a89-4de0a8624f4a.json saved successfully.
# Response for f92cd6db-7f55-4e65-b011-3e26e7eb5adf.json saved successfully.
# Response for f92da744-5900-4f89-b5f1-352497f9f342.json saved successfully.
# Response for f931daa4-59c8-46e0-a042-e62db602b554.json saved successfully.
# Response for f953b665-7fea-49c6-9c74-3dabe1b1db6d.json saved successfully.
# Response for f96525a3-70b6-407d-9fbf-e17b2aa08b64.json saved successfully.
# Response for f96538b8-e9f7-4163-93d0-05f5e7380bd8.json saved successfully.
# Response for f974f71c-c5a4-48f5-8541-e137d9ac06b2.json saved successfully.
# Response for f986ad40-6ef3-43f9-945c-d86458a74301.json saved successfully.
# Response for f988a738-758d-4ed0-80bb-6edceaf45e20.json saved successfully.
# Response for f98c075b-b8e1-4ad3-a6bc-f7341b797f2d.json saved successfully.
# Response for f9a26f76-6266-4295-8a1c-1deaa7761997.json saved successfully.
# Response for f9a31776-4ace-4af7-9688-ca02e6750f89.json saved successfully.
# Response for f9a89393-83d0-4841-8118-ed103630a76c.json saved successfully.
# Response for f9c7ad58-42f8-424e-8b28-c276a2c0b51d.json saved successfully.
# Response for f9c9d8e3-5a60-49b8-9611-a2ce811ad0d6.json saved successfully.
# Response for f9d329c8-e752-4fce-bbde-60ed82b17c0d.json saved successfully.
# Response for f9dad5d0-be02-4152-93df-0c9d07a59b3e.json saved successfully.
# Response for f9dcd09f-eab8-467f-9690-7397ee4078e8.json saved successfully.
# Response for f9efd716-591d-43c4-86c6-802f128884a7.json saved successfully.
# Response for f9fcdfff-ae5c-4437-bbce-c8aa16a59308.json saved successfully.
# Response for f9fd38b6-96ca-47b2-a6f2-258b1d6c287e.json saved successfully.
# Response for f9fd5ee6-f5b0-4010-9b1c-b722aa5e3a74.json saved successfully.
# Response for fa0edb7e-261d-4aae-9425-59e66f9feff7.json saved successfully.
# Response for fa117f9e-ff6b-4ec6-8084-20c6f0f8ff3b.json saved successfully.
# Response for fa146766-2e37-468b-9013-035e5ff1f972.json saved successfully.
# Response for fa1f7be7-40c7-4870-af3e-4bb685451682.json saved successfully.
# Response for fa272242-f5b3-4cbc-8bcd-be2ca915924c.json saved successfully.
# Response for fa2a71ae-5f24-4104-a1b7-29425104f8bb.json saved successfully.
# Response for fa2f9a0e-5570-41ae-98b1-cb529061bec6.json saved successfully.
# Response for fa31ed85-16ff-47e2-81f8-44b6ab424324.json saved successfully.
# Response for fa3dd5e4-7f25-4811-bf8c-4c2beb367ddf.json saved successfully.
# Response for fa42e007-b30f-4903-8f83-79bb6d0a49b0.json saved successfully.
# Response for fa48ac46-b2c5-425c-92c5-bfd1882a3d71.json saved successfully.
# Response for fa563433-fbe3-450f-ac37-02d20984acdd.json saved successfully.
# Response for fa56aafa-7013-4ad3-a98a-d1408bf31a05.json saved successfully.
# Response for fa59537b-f034-4ce9-8c9a-4ac536e91591.json saved successfully.
# Response for fa5d5689-cf9f-41cc-99ce-4da59731d873.json saved successfully.
# Response for fa743da9-5f38-4cb2-87df-25f6efebd535.json saved successfully.
# Response for fa7a8a6b-c67d-456b-b429-7d3811b97d3b.json saved successfully.
# Response for fa80f9ba-3371-4b94-b4a4-b725c529e34d.json saved successfully.
# Response for fa8979f1-6f12-427c-8254-9b5b328f13fe.json saved successfully.
# Response for fa8a3aee-807a-4c96-bb09-48e557e2086c.json saved successfully.
# Response for fa988010-086d-49fe-8fcb-0c1d3d931c58.json saved successfully.
# Response for fa9fe5c6-1c04-4b52-8129-99fb9a9c2209.json saved successfully.
# Response for faa501b9-8256-47c6-a057-dc73d65d4cb9.json saved successfully.
# Response for faa82ece-fef3-48a8-99f4-091bfe00ce87.json saved successfully.
# Response for faab4609-dde8-4050-9304-6b5a09e86683.json saved successfully.
# Response for fac6ba8b-4f6b-452d-a215-159b484caebf.json saved successfully.
# Response for facc7c31-ab38-4261-8391-e73fdd403a0b.json saved successfully.
# Response for fadfbaad-c388-4874-9dcc-a8dd8733d877.json saved successfully.
# Response for faf45624-b0c9-49b7-b0cd-4c972399fb80.json saved successfully.
# Response for fb01f0f2-4a42-4b8e-8172-768bb113f995.json saved successfully.
# Response for fb0d16b3-2a9b-4318-beb1-85050c418bad.json saved successfully.
# Response for fb1842b5-c077-4984-9c4c-bedad494d47b.json saved successfully.
# Response for fb1891a3-dd41-42f5-b7c3-fb3d98690ba1.json saved successfully.
# Response for fb25c42d-4422-4042-9b6c-4783d12b8c65.json saved successfully.
# Response for fb26fa52-441b-4f7c-985d-db64e1e40e43.json saved successfully.
# Response for fb29dac9-afd7-4848-9903-73497314ab96.json saved successfully.
# Response for fb37de28-7dab-42ff-bb69-816e353c6968.json saved successfully.
# Response for fb461dc0-fce8-4dcb-99ae-aab0bd0687be.json saved successfully.
# Response for fb477c9c-fc08-4f92-b4a6-8d5bf66034f7.json saved successfully.
# Response for fb496615-575b-4851-8645-24f8ba5c229d.json saved successfully.
# Response for fb56d421-0b86-4514-a81f-d26532c305d0.json saved successfully.
# Response for fb6d2f20-ccbd-4715-9e7a-b0e83e57bd30.json saved successfully.
# Response for fb72c289-a955-4faa-b936-1eb8e36dc558.json saved successfully.
# Response for fb7723ba-6fab-4a8b-9cc6-f14d22d2bd4f.json saved successfully.
# Response for fb79dcf0-8b90-489e-a4bb-bed2453c785c.json saved successfully.
# Response for fb7c1029-aab2-4567-9ec0-908e97d88458.json saved successfully.
# Response for fb7f5c48-8710-43ba-8921-74f979a66ef5.json saved successfully.
# Response for fb8e4187-eddc-4d24-a5b8-2bbd4a59db37.json saved successfully.
# Response for fb987ca8-b4f9-44bd-aba8-e434644a72ec.json saved successfully.
# Response for fb9b322b-53f7-4eff-bb39-98272b440c1c.json saved successfully.
# Response for fb9db82e-a90c-400e-8f79-8cd9802ebe2a.json saved successfully.
# Response for fb9dd92b-e127-4b4e-848f-b30e7be64e38.json saved successfully.
# Response for fbb3d85f-1822-49f0-9e67-a520af80158d.json saved successfully.
# Response for fbdfb4c7-a75a-42f9-8908-0b947a0271eb.json saved successfully.
# Response for fbe5af7e-e15e-41c3-a7df-dfccd6a21be2.json saved successfully.
# Response for fbe9fb95-fde4-4a4f-b587-acbab9e134ed.json saved successfully.
# Response for fbeef4d0-5cdb-4f5e-8163-49e19b2d1106.json saved successfully.
# Response for fbf13667-34df-499f-8543-e3bf7d898149.json saved successfully.
# Response for fbf82fc5-5d63-4a44-8a19-06c3c826fff8.json saved successfully.
# Response for fbfdaf37-6595-4dfb-b9df-57d7cad3afa3.json saved successfully.
# Response for fc0bb977-e836-4e4b-a6fe-88a55afe0dd6.json saved successfully.
# Response for fc20ef62-b536-4be0-b569-6a0b5ec6af07.json saved successfully.
# Response for fc4a148a-7f83-4a24-be27-02b414c5752d.json saved successfully.
# Response for fc5a2083-40f7-4c69-863c-c0b5a3144c8d.json saved successfully.
# Response for fc6239c1-9271-494d-9563-acd52f79fe8e.json saved successfully.
# Response for fc7ee686-dcdd-4fec-ac80-18b34817be10.json saved successfully.
# Response for fca02a98-41dd-4a5d-9a01-e62d08a61969.json saved successfully.
# Response for fcad0e91-4eb6-4f66-b53c-48584a1ba3e7.json saved successfully.
# Response for fcb0b7c1-6f15-4ea6-b730-d20cc0cc488c.json saved successfully.
# Response for fcb5a118-8a4b-4e25-9c9e-33e8b756ea5c.json saved successfully.
# Response for fcd70169-cf58-4884-bc29-4c5ffcdd8788.json saved successfully.
# Response for fcdc0d33-f3b2-4735-8ef3-c6e30329e70f.json saved successfully.
# Response for fce9d9a1-31e1-4bf5-b226-64f7ae2ba9b9.json saved successfully.
# Response for fd144aea-7f39-44a0-af44-f4ff22723c49.json saved successfully.
# Response for fd183723-ef1c-409b-9819-9bab7ea7daa1.json saved successfully.
# Response for fd1abb15-a966-4c2b-b007-43d3e18f2f48.json saved successfully.
# Response for fd1ad224-d84e-42c1-9c89-6b89ac06d960.json saved successfully.
# Response for fd1c3641-3384-4f43-9f8b-b08b579f640d.json saved successfully.
# Response for fd1c8a4f-10bc-4812-ab9d-5885b8bc82df.json saved successfully.
# Response for fd26f1d0-c7a7-4eac-9cd5-7428da790c92.json saved successfully.
# Response for fd32225a-8471-4f58-bd7d-348497019cb5.json saved successfully.
# Response for fd34c496-6db2-489d-9cb1-fd147c0c16db.json saved successfully.
# Response for fd425f2e-5838-48ad-bf6f-8a89320ac602.json saved successfully.
# Response for fd4631b3-e107-4b61-89e8-fadca7d5d92e.json saved successfully.
# Response for fd53082f-cf70-4fa6-8ec5-c954c9f6071e.json saved successfully.
# Response for fd5f2917-b883-4f59-86d4-7edf7bc00537.json saved successfully.
# Response for fd8196f8-6608-4d87-be5d-6aa2b7e4239c.json saved successfully.
# Response for fd8d6b1b-1b2d-4acb-a7c4-439c7f2bd3ff.json saved successfully.
# Response for fda6f37b-f311-4540-81ac-21bbe161469b.json saved successfully.
# Response for fdad6725-552e-4a91-a1a6-991476468da9.json saved successfully.
# Response for fdb43e04-73af-4dc5-bb80-6eecdd81cf0c.json saved successfully.
# Response for fdb626ea-2c34-4a9a-8d15-08e0b61b8b79.json saved successfully.
# Response for fdbf2f3c-bcb7-4318-800a-62ba3a0b7dba.json saved successfully.
# Response for fdc5ad8f-6750-4b9e-97ad-426b14da99db.json saved successfully.
# Response for fde2ac1e-bcd7-4f4d-8561-92ac713cd072.json saved successfully.
# Response for fde4d261-8b04-47a1-bf9f-2620b0e48124.json saved successfully.
# Response for fde723ae-dd64-4d69-ae0c-354e97011c57.json saved successfully.
# Response for fdee5ae9-88c1-4207-abcc-f2b849e08741.json saved successfully.
# Response for fdf2a8d3-b8bf-436e-822d-e09eed02c565.json saved successfully.
# Response for fdf3181e-662f-43f9-8e0d-2b984520226c.json saved successfully.
# Response for fdfd9704-ef86-43b6-a2c3-1257450533fd.json saved successfully.
# Response for fdfe73b0-390b-42dc-9db1-12bda4a11695.json saved successfully.
# Response for fe0ec2c8-f49e-4a09-8f88-6442c4ac2a16.json saved successfully.
# Response for fe19fa8e-708c-4bb3-809b-09ded27b92fb.json saved successfully.
# Response for fe24a452-afd7-4cc0-90ba-8d2057649242.json saved successfully.
# Response for fe347fe7-768b-46a5-8147-47d6d0e6b20f.json saved successfully.
# Response for fe3e68ce-aa21-41c7-9fdc-cbb46b618c9c.json saved successfully.
# Response for fe5af129-6433-49e7-ab6a-fd4821894a05.json saved successfully.
# Response for fe62bc09-af0f-4998-bd58-4c1cc6535518.json saved successfully.
# Response for fe689a29-5927-48e5-b14d-9f4ba7600e2e.json saved successfully.
# Response for fe7ed972-70c3-4d07-af8c-2ad686fce0b7.json saved successfully.
# Response for fe8dcf62-ad65-4a52-ae57-e65bfc4ff058.json saved successfully.
# Response for fe8e02db-0126-4f93-b29d-7e820cbe3b4c.json saved successfully.
# Response for fe92d7c5-1dfd-405c-8f2b-25aaadfc5e19.json saved successfully.
# Response for fe942bfe-5d30-4967-b948-38e95c379ef3.json saved successfully.
# Response for fe995a9a-cc02-479f-bb40-a418893b8328.json saved successfully.
# Response for fec6514b-0d59-43c7-92d3-f983b5461881.json saved successfully.
# Response for fed6f1c5-14dc-4814-a1f9-42793069159d.json saved successfully.
# Response for feea0839-56c4-466b-a25e-8d35d9836562.json saved successfully.
# Response for fef07d25-c170-4145-8bd3-7134fbcb5562.json saved successfully.
# Response for ff000765-14f2-44f8-a033-cc608a76237b.json saved successfully.
# Response for ff0066c5-4ac9-4eb9-82c7-30c1712cf87a.json saved successfully.
# Response for ff08316f-e1d5-4c0d-b3d9-148c8a3de1cd.json saved successfully.
# Response for ff0fc053-29d8-4f74-bcec-c28717783580.json saved successfully.
# Response for ff1ffcbe-9ee1-4b39-9a49-d5da9dc8db3e.json saved successfully.
# Response for ff2add97-fc45-4994-9df3-2cff40715e24.json saved successfully.
# Response for ff5f1f77-f292-4c43-8ef9-b801ea7e683d.json saved successfully.
# Response for ff6532bf-81c0-47d7-8cc2-c737109842b2.json saved successfully.
# Response for ff68bd9e-b83f-43b3-98b2-0de99ee14eef.json saved successfully.
# Response for ff6d2c98-8a4b-4738-ad8c-661ce80a3096.json saved successfully.
# Response for ff6ea5f4-73de-45af-950d-79720ea45fdc.json saved successfully.
# Response for ff7bbc31-2f8c-46d3-9e89-79d030cf3daf.json saved successfully.
# Response for ff8cd371-d44b-4443-b6b8-b442e8604975.json saved successfully.
# Response for ff91aef8-3cb2-46ad-94e0-9358d54b1675.json saved successfully.
# Response for ff93b243-bc6c-4459-a1b2-254a9151ed64.json saved successfully.
# Response for ff94848a-1be6-44c1-a689-196afbc44d4a.json saved successfully.
# Response for ffa761c4-0b18-481d-bb77-72ba36eec334.json saved successfully.
# Response for ffacbad5-b4f4-4fcf-85ea-655302ca219b.json saved successfully.
# Response for ffbd2a5b-be27-4bc8-95c2-be68c0e4d51f.json saved successfully.
# Response for ffc07cec-02c6-49a4-96f8-b3de84e2882f.json saved successfully.
# Response for ffc42dae-53fc-4d71-9155-785232c01762.json saved successfully.
# Response for ffc84ebc-0fea-4c5b-b45e-630daa6d4435.json saved successfully.
# Response for ffdab282-f6be-43e7-8433-1223739a597e.json saved successfully.
# Response for ffec060e-103b-41ce-8826-3d2c5282d580.json saved successfully.
# All done.

# %% [markdown]
# information parsing from OpenAlex model output

# %%
import pandas as pd
import json
import os

# Assuming the folder path is 'data/json_files', replace it with the actual path of your JSON files
folder_path = r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_text_data/text_reports_OpenAlex_processing/OpenAlex_output"

# Initialize an empty list to store the data
data = []

# Loop through each file in the specified folder
for file_name in os.listdir(folder_path):
    # Check if the file is a JSON file
    if file_name.endswith('.json'):
        # Construct the full file path
        file_path = os.path.join(folder_path, file_name)
        # Open and load the JSON file
        with open(file_path, 'r') as file:
            content = json.load(file)
            # Initialize empty lists to store tags and scores
            tags = []
            scores = []
            # Iterate through each item in the JSON data
            for item in content:
                # Filter tags and scores based on the score condition (> 0.3)
                filtered_tags_scores = [(tag, score) for tag, score in zip(item['tags'], item['scores']) if score > 0.3]
                # Unpack the filtered tags and scores
                if filtered_tags_scores:
                    tags, scores = zip(*filtered_tags_scores)
                else:
                    tags, scores = (), ()
            # Append the file name, tags, and scores to the data list
            data.append([file_name, list(tags), list(scores)])

# Create a DataFrame from the data list
df = pd.DataFrame(data, columns=['File Name', 'Concepts', 'Scores'])

# %%
df.head()
# Out:
#                                    File Name  \
# 0  000ccbf4-2c18-4d38-932b-a7521855ba75.json
# 1  0017c8ae-2d34-4a3b-9935-57eb71cb5e3e.json
# 2  002191df-1e2f-4947-97ce-c1484ed8e8fe.json
# 3  0036fdaf-627c-41ec-8fed-a5f3e7962768.json
# 4  00376492-8a56-4d02-9417-d9f42f90b3b2.json
#
#                                             Concepts  \
# 0  [platelet derived growth factor receptor, rode...
# 1  [connective tissue, follicle, cell biology, bi...
# 2   [lipofuscin, cytoplasm, chemistry, cell biology]
# 3  [vacuole, cytoplasm, multinucleate, nucleus, v...
# 4                     [dumbbell, cytoplasm, feature]
#
#                                               Scores
# 0  [0.46327659487724304, 0.4434173107147217, 0.43...
# 1  [0.5992162823677063, 0.4237041473388672, 0.349...
# 2  [0.9004032015800476, 0.6766272187232971, 0.472...
# 3  [0.8411689400672913, 0.8032214641571045, 0.661...
# 4  [0.7105890512466431, 0.5917948484420776, 0.472...

# %%
len(df)
# Out:
# 7000

# %% [markdown]
# Map concepts with UMLS

# %%
import pandas as pd
import requests
import time
from cachetools import cached, TTLCache

# Define a cache with a TTL (time-to-live) of 24 hours for search results
cache = TTLCache(maxsize=100, ttl=86400)

@cached(cache)
def search_umls(term, api_key, base_url='https://uts-ws.nlm.nih.gov/rest/search/current', pageSize=25):
    all_cuis = []
    pageNumber = 1
    totalResults = float('inf')  # Set to infinity initially to enter the loop

    while len(all_cuis) < totalResults:
        try:
            response = requests.get(f'{base_url}?string={term}&apiKey={api_key}&searchType=exact&pageSize={pageSize}&pageNumber={pageNumber}')
            data = response.json()
            results = data['result']['results']
            totalResults = data['result']['recCount']  # Total number of results for the term

            all_cuis.extend([result['ui'] for result in results])

            pageNumber += 1  # Increment page number for next iteration
        except Exception as e:
            print(f"Error processing term '{term}': {e}")
            break  # Exit loop in case of an error

    return all_cuis

@cached(cache)
def get_tuis_for_cui(cui, api_key, base_url='https://uts-ws.nlm.nih.gov/rest/content', version='2023AB'):
    try:
        response = requests.get(f'{base_url}/{version}/CUI/{cui}?apiKey={api_key}')
        data = response.json()
        semantic_types = data['result']['semanticTypes']
        return [semantic_type['uri'].split('/')[-1] for semantic_type in semantic_types if semantic_type.get('uri')]
    except Exception as e:
        print(f"Error processing CUI '{cui}': {e}")
        return []

def retrieve_cuis_and_tuis_from_umls(word_list, api_key, version='2023AB', request_delay=0.1):
    cuis = set()
    tuis = set()

    for term in word_list:
        term_cuis = search_umls(term, api_key)
        cuis.update(term_cuis)
        time.sleep(request_delay)

    for cui in cuis:
        cui_tuis = get_tuis_for_cui(cui, api_key, version=version)
        tuis.update(cui_tuis)
        time.sleep(request_delay)

    return list(cuis), list(tuis)

# Your UMLS API key
api_key = 'efd9c726-5226-43c1-8cb1-c5ac40bae98c'

# Function to map tags to CUIs and TUIs for each row in the dataframe
def map_tags_to_cuis_and_tuis(tags, api_key):
    cuis, tuis = retrieve_cuis_and_tuis_from_umls(tags, api_key)
    return cuis, tuis

# Applying the mapping function to each row in the dataframe and storing the result in new columns
df[['CUIs', 'TUIs']] = df['Concepts'].apply(lambda tags: pd.Series(map_tags_to_cuis_and_tuis(tags, api_key)))
# Out:
# Error processing CUI 'C1159342': Expecting value: line 1 column 1 (char 0)
# Error processing term 'outbreak': Expecting value: line 1 column 1 (char 0)
# Error processing term 'replication': Expecting value: line 1 column 1 (char 0)
# Error processing CUI 'C1948023': Expecting value: line 1 column 1 (char 0)
# Error processing term 'platelet': Expecting value: line 1 column 1 (char 0)
# Error processing term 'toxicity': ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error processing CUI 'C1513183': Expecting value: line 1 column 1 (char 0)

# %%
df.head()
# Out:
#                                    File Name  \
# 0  000ccbf4-2c18-4d38-932b-a7521855ba75.json
# 1  0017c8ae-2d34-4a3b-9935-57eb71cb5e3e.json
# 2  002191df-1e2f-4947-97ce-c1484ed8e8fe.json
# 3  0036fdaf-627c-41ec-8fed-a5f3e7962768.json
# 4  00376492-8a56-4d02-9417-d9f42f90b3b2.json
#
#                                             Concepts  \
# 0  [platelet derived growth factor receptor, rode...
# 1  [connective tissue, follicle, cell biology, bi...
# 2   [lipofuscin, cytoplasm, chemistry, cell biology]
# 3  [vacuole, cytoplasm, multinucleate, nucleus, v...
# 4                     [dumbbell, cytoplasm, feature]
#
#                                               Scores  \
# 0  [0.46327659487724304, 0.4434173107147217, 0.43...
# 1  [0.5992162823677063, 0.4237041473388672, 0.349...
# 2  [0.9004032015800476, 0.6766272187232971, 0.472...
# 3  [0.8411689400672913, 0.8032214641571045, 0.661...
# 4  [0.7105890512466431, 0.5917948484420776, 0.472...
#
#                                                 CUIs  \
# 0  [C0005532, C0035804, C0079107, C0007996, C0026...
# 1  [C0005532, C1571705, C0018120, C0009780, C5574...
# 2  [C0079107, C0007996, C0201682, C0010834, C1547...
# 3  [C0319157, C0005532, C0042776, C0079107, C0042...
# 4  [C2348519, C1514562, C0010834, C1706388, C2346...
#
#                                                 TUIs
# 0  [T126, T090, T169, T170, T062, T033, T059, T11...
# 1                                 [T024, T091, T023]
# 2  [T090, T169, T170, T109, T033, T123, T059, T02...
# 3  [T090, T169, T196, T170, T033, T025, T047, T00...
# 4                           [T087, T077, T026, T080]

# %%
df.to_json(r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_OA_Processes/BioRel_text_parsed_concepts_OA.json", orient='records', lines=False, indent=4)

# %%
df.to_csv(r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_OA_Processes/BioRel_text_parsed_concepts_OA.csv", index=False)
