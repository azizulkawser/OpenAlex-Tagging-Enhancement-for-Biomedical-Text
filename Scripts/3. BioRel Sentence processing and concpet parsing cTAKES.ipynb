# %% [markdown]
# Process the BioRel sentences using cTAKES. Ensure that cTAKES is installed locally and that the text report is located within the cTAKES folder.

# %%
import subprocess

class CTakesProcessor:
    def __init__(self, ctakes_dir, input_dir, output_dir, pipeline_key):
        self.ctakes_dir = ctakes_dir
        self.input_dir = input_dir
        self.output_dir = output_dir
        self.pipeline_key = pipeline_key

    def run_ctakes_pipeline(self):
        command = fr'{self.ctakes_dir}\bin\runClinicalPipeline -i {self.input_dir}\ --xmiOut {self.output_dir}\ --key {self.pipeline_key}'
        subprocess.run(command, shell=True, cwd=self.ctakes_dir)

# Example Usage
if __name__ == "__main__":
    ctakes_dir = r'C:/apache-ctakes-4.0.0.1/'
    input_dir = r'C:/apache-ctakes-4.0.0.1/BioRel_text_data' #"C:\apache-ctakes-4.0.0.1\BioRel_data"
    output_dir = r'C:/apache-ctakes-4.0.0.1/BioRel_data_cTAKES_processing'
    pipeline_key = 'efd9c726-5226-43c1-8cb1-c5ac40bae98c'

    ctakes_processor = CTakesProcessor(ctakes_dir, input_dir, output_dir, pipeline_key)
    ctakes_processor.run_ctakes_pipeline()

# %% [markdown]
# convert cTAKES XMI output to JSON

# %%
import os
import xmltodict
import json

def convert_xml_to_json(xml_file_path, json_file_path):
    with open(xml_file_path, encoding='utf-8') as xml_file:
        data_dict = xmltodict.parse(xml_file.read())
    json_data = json.dumps(data_dict)

    with open(json_file_path, 'w', encoding='utf-8') as json_file:
        json_file.write(json_data)

def convert_all_xml_to_json(xml_folder_path, json_folder_path):
    # Create the output folder if it doesn't exist
    if not os.path.exists(json_folder_path):
        os.makedirs(json_folder_path)

    # Convert each XML file to JSON
    for filename in os.listdir(xml_folder_path):
        if filename.endswith(".xmi"):
            xml_file_path = os.path.join(xml_folder_path, filename)
            # removing the extension without adding a new one
            json_file_path = os.path.join(json_folder_path, os.path.splitext(filename)[0])
            convert_xml_to_json(xml_file_path, json_file_path)

# usage
xml_folder_path = r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing"
json_folder_path = r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output"

convert_all_xml_to_json(xml_folder_path, json_folder_path)

# %% [markdown]
# extract required information from JSON output

# %%
import json
import os

# Source directory containing the files to be parsed
source_dir = r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output"

# Destination directory to save the parsed files
destination_dir = r"C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output/parsed"

# Ensure destination directory exists
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)
    

# Iterate over each file in the source directory
for file_name in os.listdir(source_dir):
    file_path = os.path.join(source_dir, file_name)

    # Check if the file is a .txt file
    if os.path.isfile(file_path) and file_path.endswith(".txt"):
        # Load the JSON data from the file
        with open(file_path, 'r', encoding='utf-8') as json_file:
            print(file_path)
            data = json.load(json_file)
            
        document_parser = {
            "UUID":[],
            "statement":[],
            "clinical_mention": {
                "textsem:SignSymptomMention": [],
                "textsem:AnatomicalSiteMention": [],
                "textsem:DiseaseDisorderMention": [],
                "textsem:ProcedureMention": [],
                "textsem:MedicationMention": [],
                "textsem:LabMention": []
                }
            }
        xmi_data = data.get("xmi:XMI", {})
        
        def process_umls_concepts(umls_concept_data):
            umls_concepts = {}
            if isinstance(umls_concept_data, dict):  # Single UMLS Concept
                xmi_id = umls_concept_data.get("@xmi:id", None)
                if xmi_id is not None:
                    umls_concepts[xmi_id] = {
                        "cui": umls_concept_data.get("@cui", ""),
                        "tui": umls_concept_data.get("@tui", ""),
                        "preferredText": umls_concept_data.get("@preferredText", "")
                        }
            elif isinstance(umls_concept_data, list):  # List of UMLS Concepts
                for concept in umls_concept_data:
                    xmi_id = concept.get("@xmi:id", None)
                    if xmi_id is not None:
                        umls_concepts[xmi_id] = {
                            "cui": concept.get("@cui", ""),
                            "tui": concept.get("@tui", ""),
                            "preferredText": concept.get("@preferredText", "")
                            }
            return umls_concepts

        # # Extract UMLS Concepts data and process it
        umls_concepts_data = data.get("xmi:XMI", {}).get("refsem:UmlsConcept", {})
        umls_concepts = process_umls_concepts(umls_concepts_data)
        
        for mention_type, mentions_list in xmi_data.items():
            if mention_type.startswith("structured:DocumentID"):
                UUID = mentions_list.get("@documentID")
                document_parser["UUID"].append(UUID)
            elif mention_type.startswith("cas:Sofa"):
                sofa = mentions_list.get("@sofaString")
                document_parser["statement"].append(sofa)
            elif mention_type.startswith("textsem:"):
                # Check if the mention type exists in clinical_mention
                if mention_type in document_parser['clinical_mention']:
                    if isinstance(mentions_list, list):
                        for mention in mentions_list:
                            mention_info = {  # Extract necessary information from each mention
                                "beginOffset": mention.get("@begin", ""),
                                "endOffset": mention.get("@end", ""),
                                "ontologyConceptArr": mention.get("@ontologyConceptArr", ""),
                                "confidence": mention.get("@confidence",""),
                                "polarity": mention.get("@polarity", "")
                                # Add more fields as required
                            }
                            
                            # # Extracting matching lemmas
                            matching_tokens = []
                            matching_lemmas = []
                            for node in xmi_data.get("syntax:ConllDependencyNode", []):
                                if int(mention.get("@begin", "")) <= int(node.get("@begin", "")) and int(mention.get("@end", "")) >= int(node.get("@end", "")):
                                    matching_tokens.append(node.get("@form", ""))
                                    matching_lemmas.append(node.get("@lemma", ""))
                            mention_info["token"] = " ".join(matching_tokens)
                            mention_info["lemma"] = " ".join(matching_lemmas)
                            
                            # Extracting matching parts of speech
                            matching_POS = []
                            for node in xmi_data.get("syntax:WordToken", []):
                                if int(mention.get("@begin", "")) <= int(node.get("@begin", "")) and int(mention.get("@end", "")) >= int(node.get("@end", "")):
                                    matching_POS.append(node.get("@partOfSpeech", ""))
                            mention_info["partOfSpeech"] = " ".join(matching_POS)
                            
                            # Extract CUI and TUI from the ontology concept array
                            ontology_ids = mention.get("@ontologyConceptArr", "")
                            if ontology_ids:
                                if " " in ontology_ids:
                                    ontology_ids = ontology_ids.split()
                                else:
                                    ontology_ids = [ontology_ids]
                                
                                # Loop through each ontology ID
                                for ontology_id in ontology_ids:
                                    umls_info = umls_concepts.get(ontology_id, {})
                                    mention_info["cui"] = umls_info.get("cui", "")
                                    mention_info["tui"] = umls_info.get("tui", "")
                                    mention_info["preferredText"] = umls_info.get("preferredText", "")
                            
                                document_parser['clinical_mention'][mention_type].append(mention_info)
                            
                    elif isinstance(mentions_list, dict):  # In case there is only one mention and it's not in a list
                        mention_info = {
                            "beginOffset": mentions_list.get("@begin", ""),
                            "endOffset": mentions_list.get("@end", ""),
                            "ontologyConceptArr": mentions_list.get("@ontologyConceptArr", ""),
                            "confidence": mentions_list.get("@confidence",""),
                            "polarity": mentions_list.get("@polarity","")
                        }
                        # Extracting matching lemmas
                        matching_tokens = []
                        matching_lemmas = []
                        for node in xmi_data.get("syntax:ConllDependencyNode", []):
                            if int(mentions_list.get("@begin", "")) <= int(node.get("@begin", "")) and int(mentions_list.get("@end", "")) >= int(node.get("@end", "")):
                                matching_tokens.append(node.get("@form", ""))
                                matching_lemmas.append(node.get("@lemma", ""))
                        mention_info["token"] = " ".join(matching_tokens)
                        mention_info["lemma"] = " ".join(matching_lemmas)
                        
                        # Extracting matching parts of speech
                        matching_POS = []
                        for node in xmi_data.get("syntax:WordToken", []):
                            if int(mentions_list.get("@begin", "")) <= int(node.get("@begin", "")) and int(mentions_list.get("@end", "")) >= int(node.get("@end", "")):
                                matching_POS.append(node.get("@partOfSpeech", ""))
                        mention_info["partOfSpeech"] = " ".join(matching_POS)
                        
                        # Extract CUI and TUI from the ontology concept array
                        ontology_ids = mentions_list.get("@ontologyConceptArr", "")
                        if ontology_ids:
                            if " " in ontology_ids:
                                ontology_ids = ontology_ids.split()
                            else:
                                ontology_ids = [ontology_ids]
                            # Loop through each ontology ID
                            for ontology_id in ontology_ids:
                                # print(ontology_id)
                                umls_info = umls_concepts.get(ontology_id, {})
                                mention_info["cui"] = umls_info.get("cui", "")
                                mention_info["tui"] = umls_info.get("tui", "")
                                mention_info["preferredText"] = umls_info.get("preferredText", "")
                            
                            document_parser['clinical_mention'][mention_type].append(mention_info)
                        
        # Save the parsed data to the destination directory
        output_file_path = os.path.join(destination_dir, file_name)
        with open(output_file_path, 'w', encoding='utf-8') as output_file:
            json.dump(document_parser, output_file, indent=4)
# Out:
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\000ccbf4-2c18-4d38-932b-a7521855ba75.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0017c8ae-2d34-4a3b-9935-57eb71cb5e3e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\002191df-1e2f-4947-97ce-c1484ed8e8fe.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0036fdaf-627c-41ec-8fed-a5f3e7962768.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\00376492-8a56-4d02-9417-d9f42f90b3b2.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\00540d0f-b986-4d6b-bc57-ea78a5f819e4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\005aa28d-d3e5-4df4-a91f-ed6c64c1bc78.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0060558a-f0af-4e16-9737-84f1c3d3f95c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0063bb1f-10f7-4fda-9a87-12937fad72e7.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0069a702-1a9c-4384-a4f8-aeb5a00b10e4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\007612fb-f7d4-41e2-bd97-e681f623d5ae.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0077cf43-98c7-47e1-958c-d6e463c55ff4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\007ab615-609c-4703-a740-6d48fd9b60e8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\00817c35-b348-4c0c-ae73-143334075b31.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\00830bb5-1327-4ffe-853a-be0af8bce04c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\00d13554-ad8b-4e9b-bdb8-f26ae59dc5c3.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\00e4da9f-4dd2-4591-9f2c-028a07dba374.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\00ee255e-37c9-4efc-b295-e017036161b4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01081321-a790-45c2-a1de-713cb1419c55.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0112bf83-749b-4eb8-baca-05ff3e8d621b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0116233d-057b-43b8-ab26-aa7e1ccb5324.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\011cc6c2-b987-4756-bb5f-83f6b0c0e879.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0122e0a6-a628-453c-83ae-d04dbae54a48.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\012da390-b739-4ed0-8e24-07eef8bf6b18.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0136af12-71de-4ce7-92e3-024064f0bbf4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\013a7fe1-eacd-4a9c-aca9-d5926005fbed.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\013c464a-c193-4fe5-bb6a-9bbc902b5040.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0142a1ea-4bdd-462c-8118-c780715257d4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0144ada8-c4f9-4de5-93b7-2ae4838a6e33.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01636a0c-edf1-4a56-9ce7-43dae1562859.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\016dd5a0-0a77-4657-9482-3e1d09cfe356.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01801ae4-6e06-4b53-b9ec-f283050e0a01.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0181b5bc-d476-465b-b6f5-c4f66fbc32d0.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\018adaa3-d4fb-4306-9f80-7974d4fa868b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\018fcda7-7570-4c28-abd7-e93508574c68.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01b1ca9b-aa15-4740-9e84-31daff72f475.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01b54e55-6f04-425f-9da7-6a1e311d178b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01be8f6d-52bc-4409-ac4d-abefa79027b2.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01c42509-8e8a-47c9-b5a1-b81351f7d15f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01c9ef3a-de06-414d-b448-1f9a00a1a0fe.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01e20cc0-1410-4016-9520-c72e097f1ace.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01e6d716-7df7-4740-927a-a93ac3030a4e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\01f671a5-13e6-4d6a-a531-88dd83a27a5e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\020314aa-2b38-4d05-b31d-b201540cc28e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02058fff-7513-42db-9f0e-e9205d1c4875.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0213d369-405f-4482-8205-36dffb8fb5ad.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0214111c-e20b-4c0c-9d90-aebec17c6826.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0214f4ea-4532-4db8-a9d5-98fa7a088c30.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02157134-85c0-46a7-a07f-1e781855dcd8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\021785a5-719c-4b76-b4c8-23a20d490028.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0218ca0b-1bed-4875-bf3c-9e74be51a6f1.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0258f053-8e74-4115-b3a6-7ac79824de9b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0259f8e8-7b29-4b93-8059-8c58973ee4a8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\027a16cd-3430-41a4-89c4-231296982e44.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\028aa4a9-d30f-4610-9d61-a877e1f5a239.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\029619eb-c876-4d92-bd24-082346564ffc.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\029cae52-015e-4d41-917c-8c6047d718c7.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02b1d3f2-9cab-40f7-ad5e-ac0babc923cf.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02bc377a-a745-45db-9c83-991110a5330e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02c6eaff-211c-463b-8621-bc7c48e0c81f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02c991b3-a480-473a-93b7-4cba1927d098.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02d2f327-b266-4d89-9d86-334914ab3816.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02d3083c-194a-4f84-af4d-df588862e5ad.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02dbc72e-0733-4bd4-91d6-1cb29e921d16.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02dd81e0-2147-4d2c-b49a-39c522d81893.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02e14000-27c0-41c7-a65b-7cb99c950179.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02ed1a6b-379b-4e53-8b34-e000416c10d2.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02f6bea6-d58f-4db0-9d12-0ddee8c9f3f7.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02fbe607-6ef2-4b04-8260-3ad1c05244b2.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02fc499b-19cf-4a2d-992f-8ceb23ac97eb.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\02fc8892-3ff4-4b8f-91ac-76263e555e1d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\030d9a7c-d99a-4f92-af99-d65a5d0ce859.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\031325a8-eeef-4b1d-8e5f-987318e7f752.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0324666d-dda9-473f-a183-734b72873319.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\032504fe-f86d-4c94-a09a-383be3caf5a5.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\033121e6-4c8a-4d9f-9f93-83e61748e3ad.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03361d51-3182-4c95-bd48-9790416b620d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03368a04-9d20-4b74-befb-584239a0f379.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\033d6cfb-ebd8-4ff6-8c3e-53e8f6b48869.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\034345fe-53ee-4c93-899a-1df78a7451f9.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\034fe469-213d-42fa-91c0-d3318a89dc07.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0370a255-c6d0-4791-a685-9f6cb4315713.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0371023c-c065-4080-8cf7-2144008c75c0.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0379ac6e-9fde-4e91-acf5-7a62a3556db3.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0379e554-ce68-44a4-bb56-d00781c13835.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03815c8a-14d3-435f-a850-e195666782fc.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03844ddd-c17a-419f-b1fe-41cb902a252c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03874344-7590-471d-bcd1-164c2de05bca.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0389c1b9-4e77-40be-a918-0a5ae4638e3d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\039befe5-6981-4fbb-a035-b6d5eba42aae.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\039d77b1-3493-4f8d-b009-47b4e8f8f051.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03a1fca3-1015-4177-824d-0f1e7c7ec454.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03bd9530-5b7c-4437-b693-772e5300cd51.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03c6073b-3245-4bbb-9a1e-0e6dbbeb15ab.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03c66bcb-0d56-472f-aaea-db0d08498452.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03c85337-4c11-411e-be97-466c7690e944.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03d894c7-1894-4d88-b4ae-e891815023df.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03df4d32-4dc7-4db9-a6ae-7b424069e721.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\03fc82f6-2354-4e3a-af95-d1135421b9ef.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0404a05f-1dfa-44a5-a3c0-573934c9789c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\041294e4-3ce8-47be-a190-2f19d58031b8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0424c1b3-8371-4bb1-b8ce-1a4f56d8648d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0428cb77-5dd2-41d3-8cd5-25b5e6e724cf.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0429bcc3-b5f8-4676-8c3a-e2dfea053b8d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\042cc948-40f0-4cef-9ae9-44e78e102475.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0430f5b7-f9ad-4034-846e-d46d87cb0512.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0434eb17-14a4-45f6-a494-1cc776731d42.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\04591797-d176-461b-9c28-055c81466d1a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\04591a50-dba5-46e6-9fec-b4cba494505a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\045a37a7-33da-4644-a0e1-bc6f2826756e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\045e3b8a-ab21-4f55-a93f-4305c861c36d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\045f8f1b-ef8e-4662-aaca-7fbf1a1087c4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0470ed73-5889-4dcc-8e24-636ffe7ae5de.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0472e9ce-c6f9-4bc6-82a6-372d631d6f1e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\047dc4e5-ee2d-4a49-abb0-7394a55642c4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0481f817-eb5a-406c-92dc-ee2cab755a25.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\04924865-ccff-489b-8ce7-0bbb20910e9a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0494450b-cb3b-4452-a2e4-9a1df93a0d7b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\04976e4b-a744-4864-8492-75e202bce2f3.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\049ab05f-0032-48c0-92a9-24b4836d99b8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\04c13bb8-b967-4c5d-a271-99cf07610271.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\04d32d53-eb09-4f8c-b361-d301b6f776f0.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\04d84bea-176a-4e0b-956f-c422dff7c91a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\04f113d5-38e0-4922-866a-79ac7771836a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\050312a1-0328-4418-ab02-44c116db8a89.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\052c89b1-930d-4015-abc4-9dccc26280ae.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05305bb3-a914-444c-ad54-d1e10072dc27.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\053515d7-b63f-4669-8cd7-5efa3a38ae79.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\053910ba-5fda-4aef-b94b-5df70621fe17.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\053c4602-a4ea-469e-8a59-dcc625b40ae9.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05429a9f-dcf7-493b-8052-258fad608e7e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\054af036-810f-482d-809b-7455536420db.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\055312be-1fe4-47a3-b167-759e2a298b9f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0555dd2e-9cbc-496d-b509-e937f4c4707b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0558abda-2c92-4f4b-87bc-96a2e045a87e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0558bf67-8e3c-46eb-ac28-fa39b438b87f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\055fd0da-8ab1-4f37-9519-396f0b6a0466.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\056f8d53-0960-4997-9654-4656d6b3e839.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05777a30-1a3d-49ff-9b1c-be2190e8d938.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0587c9cc-c35b-4abd-8891-728ca9dde7ce.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0594003a-bc35-4cb0-8afb-23a9f9cfa1bd.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05ab005c-356f-485b-8881-123687671630.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05ac01f2-c8c1-4bd5-9682-d499ad7cbe02.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05bdd8cd-827d-47bc-9fdd-7030caa8e0b4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05be238a-8c77-4efe-952e-0dfabfef80aa.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05c37be7-adcd-41ac-8851-fe9280900451.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05c52205-9025-4110-87d0-6d5bd028945b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05d88a3b-8244-4347-a042-2a16552c906c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05ddb1e5-ae0d-4451-9764-e823d1400586.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05e865ff-acc0-4d0f-a2c2-b4f6cfcf0a71.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05ee3df8-75d6-45c6-b9fc-a31c754447d8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05f71122-fee8-4256-b12c-b85a0a636909.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05f92c63-86ee-444b-9350-f7f518a80353.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05fa8924-4a13-4e67-942e-b4b9aebf3dda.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\05ff7b8a-3c4a-4d7e-98c4-c330d687673e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0607281c-927a-4765-b9a1-68c5463939fa.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0608ae33-88be-42f1-b1a6-e6095129be1f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\060e2d0b-b3fd-4aa2-a296-eb4480d0e531.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06154dcf-0cab-4eba-92a0-5cce9bdbaf2a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\061b4eaf-e586-46dd-b27e-30f4ec23adc9.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\061ecb92-aefb-42dc-a090-40ea4d6a1eed.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\062680ff-2280-4041-9fbd-677b002bec50.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\063f1222-780d-44b3-a77e-00633d787d02.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\063f8655-ba47-45dd-9ac2-25a29d190243.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\064a8151-9b50-4708-8bb2-2a4c4eaa8728.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\064d623a-9b66-44b4-b3da-6bf800f7b08b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\064f1fb2-d41e-4bc7-90da-07a4a2e370ce.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0651995f-091d-4b76-b868-a052c669a17f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0652f78a-47b5-46e1-94ed-fdcc1b32040f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\065d716b-322d-4c3c-a783-a043ef1a5143.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\065ffbb8-580c-4b44-bc30-5ade85e6dad3.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06620636-c4cc-4911-abf1-f4462b72cc16.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\066369e2-a847-46c2-b9de-f78f52d74f1d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0665c5ed-cc25-47c9-a890-cb6017b5d368.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\066c1378-b758-4f99-a467-e94d35d324f4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\066c1e21-5e75-431b-992f-5b8caccade3e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0676ccee-35ea-4930-90b9-3359492c70aa.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06816e5e-867d-4dfb-a9c7-d6efe1e8f6ad.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0683c926-eef4-42bd-b072-a92d8a0d7ccc.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\068dbc7e-68df-4eab-b679-41ae2ed2cc57.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\069747f1-1931-4fe0-afd7-f3c9d9d1b213.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\069bd869-e9e2-44e8-a6af-7b087e5fdb10.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\069f382c-8d4d-4811-8146-0b29bbf5fe48.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06a2c9fb-b899-4105-87c3-73a7bd398e02.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06a8d002-4a53-4009-919e-7410487d639e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06a925c1-b873-47ea-b321-aefc29a88ff8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06abb46e-cae1-41ef-9b0b-da5b22a51597.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06b5a461-abbb-40d8-974b-7dc75dd24804.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06b6dfdc-279c-424b-a093-09fd4af01d3f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06be8e0c-f009-4c4a-b43a-ceee741553d2.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06cecad5-20b4-4482-8839-7177575150c5.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06d1c401-8ee4-4758-a5ab-54dd306ae014.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06d25c1a-83de-4e7b-a2b6-1c5e1f99c49e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06d5fca3-6540-4431-9a95-ce5b1ef4ee95.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06dd1292-8782-4eae-bfae-5b66f5c04f79.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06e10cc0-56b0-4725-834e-b6459990216c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06e4a31e-8f24-4613-8957-cc229048d744.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06e5d984-6c54-49a9-8f55-52e3c135d880.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\06f02cdf-6158-40f4-acb4-aaea19f8d533.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\070b756d-6257-46e2-8eb5-a0b1feeccaf8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0711fd8d-e462-4bda-a6e6-a7244656892d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\072e1628-4433-405f-afdb-badf430c652b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\072fc422-5056-42a8-9866-0daea1ebd90e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\073b4184-6dd2-4586-9d0f-a896b3a1b923.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\073f084a-4e25-4415-aa26-a2f89a61cc22.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07449ef9-8d75-41be-ad30-924ab46b644e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\074c0478-e10f-458a-9a39-dce58a8102ec.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\075227d1-dc7c-45eb-a6da-9b1756728c2b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07540d24-7939-4bab-b498-17978ab6523c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\075429e3-f22e-4ff5-8849-cb170f833dd8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\076f8cf8-7a99-4bf5-8d29-69fb4627978c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0770ccde-1868-42e9-9cd3-d8bf16648967.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07786811-81a7-49bf-aad1-2bdb8114475d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\077af874-f964-4dbf-9d15-4615b50efc4a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\077ecfb3-c9dd-4f7c-bf2a-afc3a1d68d97.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\078f7ed6-038f-4a1f-88ab-708fd7d18f42.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07909a7f-cae5-4ad8-87a7-fcbffb32eafd.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07973ed7-1826-472c-a6ed-1304356327dd.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\079ddb5f-ab25-465e-9221-aee4deb8db1a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07a7c556-4d18-4439-a9a6-16f916481ca7.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07b94d7c-c06a-4b86-846a-492cc86cd33c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07bbc2eb-cae5-43ca-b8b4-c0d6054c69db.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07c00c90-c534-4495-9f90-b1eeadf0de3e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07c73d9c-5937-4e28-82a5-9f5515097cea.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07d8c7b9-5620-4d56-b41a-d5b5fa63a535.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07dc6d7b-7c0a-4590-93e3-433f7567fef4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07ddcfa0-d494-4aa2-b28f-7ac852c2a187.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07df7224-b4d5-46eb-810a-35a59cb923ac.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07e7b4dd-ee90-4da1-ac1e-c3f5c22f96af.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07ec4367-d2e7-4b2c-890f-7a7c8026b371.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07f0a475-4777-416a-886b-11177b7a68f8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\07fe88bb-d173-4114-930e-16f312b051d5.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0817b693-13eb-4a95-b86a-ad79db09a21b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\082e9312-acd9-4cb6-91cd-43c0fa7578aa.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\083cbf0a-d369-45f1-98c9-d36a72b66888.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\084982b4-a4cb-40dc-b053-237e9bcd667c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\085349e4-2261-4e70-94b8-ba0b64099dd7.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08571014-35b6-41bc-b025-1ed4a48d72be.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\085f08bd-2949-4fdd-a7fb-5ae8a3056b23.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\086e5d9b-653d-4dbc-8e8e-0decfcfb44c8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\086fb204-f294-45aa-afbf-ffc47c228047.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\089c460c-961d-4cb1-bac1-aaa709457918.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\089e95df-1fe1-4cdf-a78e-56085c432613.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08a5df7b-83d0-4e5a-80a4-c9bdb411ee85.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08a6b1b0-734f-4e4f-bf50-3c1e10a2d348.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08ceb454-c303-4e94-ad38-bd66c724a48a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08d59b46-bf9c-4179-8acd-e38a9c1a8c6e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08d743f4-3b8a-49e6-919d-2749d67126b0.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08dba95d-8d9d-412b-b10c-ce6fc29dcc9b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08e1a96d-7532-4f74-a351-c7c65f1be585.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08e64861-7d8e-43bc-ab95-6b9cd90e8b9c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08e8461e-48a2-4d40-a580-cb88dd078a77.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08f380ff-b8f3-44a9-b781-30131a66dfbb.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\08fb8112-b39d-470e-a642-f0ff505c372e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0906b92c-6721-44f6-8798-bc83cf077c26.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\090ba908-0972-4874-9acf-2caf45a022be.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09168d3b-0152-430d-a74a-31fa44ae7e97.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09262be4-667d-4e9e-a15b-c74d90d5f374.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0930f863-3a33-41d4-9f36-24995d188a65.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0936ed8e-709d-416d-be82-b68cb06c3f18.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09423f30-9459-4c3c-a272-e786a9bce9c0.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0942d114-56d4-43ae-906f-3015aba78c4e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\094600ff-0bfc-4e43-bc55-4410012e5ca7.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\094ec826-c99f-495c-9ae1-a228e11e0954.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\095b0ef7-6024-4887-acc0-08d68ef59f0e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\095fcfe3-03ce-445f-9023-3ba7f82b981a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\096364bc-a667-415c-82da-ce0cc02c6d15.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\096a6216-8d44-4083-84ad-aafad9da6d88.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09702f92-7928-4dec-814f-cc56399a9976.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0970b024-8cad-44b1-b386-797af2305d8b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0970d89f-a4f6-451f-bd64-63e0dbc1bd91.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\097fcefe-3edf-4ba2-83bb-5005ccd3a1f4.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09968174-f30e-4457-8caa-e2738a2ee58e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\099ac417-9d80-4498-826a-07e146d161d6.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09a30655-eb42-4eff-a635-20880565bef1.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09abf01e-9870-49ac-ad0a-01632fc9bd0d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09acd2aa-4136-4436-bf3b-447b5e712f21.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09aee295-a3af-4e57-b621-3a7b28c35770.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09afe017-b934-4b32-aa88-7bfbcb70b7a9.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09b228ad-c18e-4010-a52c-8ffa651c3d52.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09b439d7-eeb6-4751-819e-93e008c7465b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09be7097-de31-440e-97d8-3c0d4435e3b5.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09bf622b-ba10-4bbf-83aa-e23a03b5ac5d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09c19d3a-a260-4561-bf7c-289d72180bde.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09d38327-7de9-4180-85b6-8d04b236d2e9.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09ebe123-e407-4b75-91e7-75e43abb8260.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09f5da7f-f9ea-4a55-9372-87a2e4dc9f30.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09f74770-5df3-42f2-b849-06de7c70e21f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\09fe4db6-747e-4e97-8909-5017bd371089.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a04f077-2073-4c2b-b712-5a107eec2dec.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a078f61-e68a-4670-aed6-87210eefd46c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a123c82-6e98-4786-ad4d-48e46b3c705e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a1262ca-f1d8-450f-a61a-3d62f7ea5525.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a15d21d-05b7-47b7-859b-01de3aa23628.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a19b75f-05dc-43bb-b7d5-7675c4b66ea6.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a1fe1ed-bc4e-4696-b85a-995ed49b2e45.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a323501-a942-4e11-a25f-f59eefb8e19a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a356315-7f86-4fce-aeb9-6aa92dfbdf5a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a3a9cbf-e787-4fe5-942b-6f9ac214734f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a486f52-920d-46a7-878b-268bb757e9cb.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a4cce32-c3f1-458a-a2dc-81b319abbb37.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a508ac0-09e7-465d-bd9e-86e230c955fc.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a540302-8ebb-4604-8725-10770e805b31.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a543340-8816-4ab8-a5e3-3f2483a2b84e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a5b64ae-834f-465f-aa3a-ac17d5c07dfe.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a5f75fc-464a-4bb3-8688-cd0eedecf703.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a6e8624-6360-4730-a188-15893ac1bebd.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a7040f4-7473-4ff1-abc7-f2f4cf57b044.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a7222aa-4100-43a9-b494-cc1089a98f10.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a755224-7747-4703-916b-d351e58f1662.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a855d19-6a60-4954-9588-3688ea8252a3.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a89a32d-ce3d-4869-8cc7-2aca431d78f5.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a8c20d6-c96d-45d9-8174-2c3c59ac04b0.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0a8f7372-1ce7-4b55-8391-164784be2d50.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0aa7c4ba-40ef-44ef-b21f-6a0e5f29a23b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0aaa7e67-6d53-4406-879f-0bfb3247fcb9.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0aab31f7-1c44-4b0d-88e1-1700b61baa21.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0aaccc98-c15a-4acf-a2f7-4b7e467855bf.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0acc3fb5-d5d1-4a03-9918-222dec379528.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\0ad12c54-cf62-4b5b-817f-cef846c6868e.txt
# ...
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb477c9c-fc08-4f92-b4a6-8d5bf66034f7.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb496615-575b-4851-8645-24f8ba5c229d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb56d421-0b86-4514-a81f-d26532c305d0.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb6d2f20-ccbd-4715-9e7a-b0e83e57bd30.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb72c289-a955-4faa-b936-1eb8e36dc558.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb7723ba-6fab-4a8b-9cc6-f14d22d2bd4f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb79dcf0-8b90-489e-a4bb-bed2453c785c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb7c1029-aab2-4567-9ec0-908e97d88458.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb7f5c48-8710-43ba-8921-74f979a66ef5.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb8e4187-eddc-4d24-a5b8-2bbd4a59db37.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb987ca8-b4f9-44bd-aba8-e434644a72ec.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb9b322b-53f7-4eff-bb39-98272b440c1c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb9db82e-a90c-400e-8f79-8cd9802ebe2a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fb9dd92b-e127-4b4e-848f-b30e7be64e38.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fbb3d85f-1822-49f0-9e67-a520af80158d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fbdfb4c7-a75a-42f9-8908-0b947a0271eb.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fbe5af7e-e15e-41c3-a7df-dfccd6a21be2.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fbe9fb95-fde4-4a4f-b587-acbab9e134ed.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fbeef4d0-5cdb-4f5e-8163-49e19b2d1106.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fbf13667-34df-499f-8543-e3bf7d898149.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fbf82fc5-5d63-4a44-8a19-06c3c826fff8.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fbfdaf37-6595-4dfb-b9df-57d7cad3afa3.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fc0bb977-e836-4e4b-a6fe-88a55afe0dd6.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fc20ef62-b536-4be0-b569-6a0b5ec6af07.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fc4a148a-7f83-4a24-be27-02b414c5752d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fc5a2083-40f7-4c69-863c-c0b5a3144c8d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fc6239c1-9271-494d-9563-acd52f79fe8e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fc7ee686-dcdd-4fec-ac80-18b34817be10.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fca02a98-41dd-4a5d-9a01-e62d08a61969.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fcad0e91-4eb6-4f66-b53c-48584a1ba3e7.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fcb0b7c1-6f15-4ea6-b730-d20cc0cc488c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fcb5a118-8a4b-4e25-9c9e-33e8b756ea5c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fcd70169-cf58-4884-bc29-4c5ffcdd8788.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fcdc0d33-f3b2-4735-8ef3-c6e30329e70f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fce9d9a1-31e1-4bf5-b226-64f7ae2ba9b9.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd144aea-7f39-44a0-af44-f4ff22723c49.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd183723-ef1c-409b-9819-9bab7ea7daa1.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd1abb15-a966-4c2b-b007-43d3e18f2f48.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd1ad224-d84e-42c1-9c89-6b89ac06d960.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd1c3641-3384-4f43-9f8b-b08b579f640d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd1c8a4f-10bc-4812-ab9d-5885b8bc82df.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd26f1d0-c7a7-4eac-9cd5-7428da790c92.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd32225a-8471-4f58-bd7d-348497019cb5.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd34c496-6db2-489d-9cb1-fd147c0c16db.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd425f2e-5838-48ad-bf6f-8a89320ac602.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd4631b3-e107-4b61-89e8-fadca7d5d92e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd53082f-cf70-4fa6-8ec5-c954c9f6071e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd5f2917-b883-4f59-86d4-7edf7bc00537.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd8196f8-6608-4d87-be5d-6aa2b7e4239c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fd8d6b1b-1b2d-4acb-a7c4-439c7f2bd3ff.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fda6f37b-f311-4540-81ac-21bbe161469b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fdad6725-552e-4a91-a1a6-991476468da9.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fdb43e04-73af-4dc5-bb80-6eecdd81cf0c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fdb626ea-2c34-4a9a-8d15-08e0b61b8b79.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fdbf2f3c-bcb7-4318-800a-62ba3a0b7dba.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fdc5ad8f-6750-4b9e-97ad-426b14da99db.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fde2ac1e-bcd7-4f4d-8561-92ac713cd072.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fde4d261-8b04-47a1-bf9f-2620b0e48124.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fde723ae-dd64-4d69-ae0c-354e97011c57.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fdee5ae9-88c1-4207-abcc-f2b849e08741.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fdf2a8d3-b8bf-436e-822d-e09eed02c565.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fdf3181e-662f-43f9-8e0d-2b984520226c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fdfd9704-ef86-43b6-a2c3-1257450533fd.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fdfe73b0-390b-42dc-9db1-12bda4a11695.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe0ec2c8-f49e-4a09-8f88-6442c4ac2a16.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe19fa8e-708c-4bb3-809b-09ded27b92fb.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe24a452-afd7-4cc0-90ba-8d2057649242.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe347fe7-768b-46a5-8147-47d6d0e6b20f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe3e68ce-aa21-41c7-9fdc-cbb46b618c9c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe5af129-6433-49e7-ab6a-fd4821894a05.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe62bc09-af0f-4998-bd58-4c1cc6535518.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe689a29-5927-48e5-b14d-9f4ba7600e2e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe7ed972-70c3-4d07-af8c-2ad686fce0b7.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe8dcf62-ad65-4a52-ae57-e65bfc4ff058.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe8e02db-0126-4f93-b29d-7e820cbe3b4c.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe92d7c5-1dfd-405c-8f2b-25aaadfc5e19.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe942bfe-5d30-4967-b948-38e95c379ef3.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fe995a9a-cc02-479f-bb40-a418893b8328.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fec6514b-0d59-43c7-92d3-f983b5461881.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fed6f1c5-14dc-4814-a1f9-42793069159d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\feea0839-56c4-466b-a25e-8d35d9836562.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\fef07d25-c170-4145-8bd3-7134fbcb5562.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff000765-14f2-44f8-a033-cc608a76237b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff0066c5-4ac9-4eb9-82c7-30c1712cf87a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff08316f-e1d5-4c0d-b3d9-148c8a3de1cd.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff0fc053-29d8-4f74-bcec-c28717783580.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff1ffcbe-9ee1-4b39-9a49-d5da9dc8db3e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff2add97-fc45-4994-9df3-2cff40715e24.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff5f1f77-f292-4c43-8ef9-b801ea7e683d.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff6532bf-81c0-47d7-8cc2-c737109842b2.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff68bd9e-b83f-43b3-98b2-0de99ee14eef.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff6d2c98-8a4b-4738-ad8c-661ce80a3096.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff6ea5f4-73de-45af-950d-79720ea45fdc.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff7bbc31-2f8c-46d3-9e89-79d030cf3daf.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff8cd371-d44b-4443-b6b8-b442e8604975.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff91aef8-3cb2-46ad-94e0-9358d54b1675.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff93b243-bc6c-4459-a1b2-254a9151ed64.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ff94848a-1be6-44c1-a689-196afbc44d4a.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ffa761c4-0b18-481d-bb77-72ba36eec334.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ffacbad5-b4f4-4fcf-85ea-655302ca219b.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ffbd2a5b-be27-4bc8-95c2-be68c0e4d51f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ffc07cec-02c6-49a4-96f8-b3de84e2882f.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ffc42dae-53fc-4d71-9155-785232c01762.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ffc84ebc-0fea-4c5b-b45e-630daa6d4435.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ffdab282-f6be-43e7-8433-1223739a597e.txt
# C:/OpenAlex Tagging Enhancement for Biomedical Text/Scripts/BioRel/BioRel_data_cTAKES_processing/json_output\ffec060e-103b-41ce-8826-3d2c5282d580.txt

# %% [markdown]
# Combine into single dataset

# %%
import pandas as pd
import json
import os

# Define the directory containing your JSON files
json_dir = "C:\OpenAlex Tagging Enhancement for Biomedical Text\Scripts\BioRel\BioRel_data_cTAKES_processing\json_output\parsed" #"C:\OpenAlex Tagging Enhancement for Biomedical Text\Scripts\BioRel\BioRel_data_cTAKES_processing\json_output\parsed"

# Initialize a list to hold data for each file
data_list = []

# Loop through each file in the directory
for filename in os.listdir(json_dir):
    if filename.endswith('.txt'):  # Check if the file is a JSON file
        file_path = os.path.join(json_dir, filename)
        
        # Open and load the JSON file
        with open(file_path, 'r') as file:
            data = json.load(file)
            
            # Extract UUID
            uuid = data["UUID"][0]  # each JSON file contains only one UUID
            
            # Initialize lists to collect CUIs, TUIs, and tokens
            cuis, tuis, tokens = [], [], []
            
            # Loop through each mention type and collect the required information
            for mention_type, mentions in data["clinical_mention"].items():
                for mention in mentions:
                    cuis.append(mention["cui"])
                    tuis.append(mention["tui"])
                    tokens.append(mention["token"].strip())  # Stripping any leading/trailing whitespaces
            
            # Append the extracted information to the data list
            data_list.append({
                "File_name": uuid,
                "Tokens": tokens,
                "CUIs": cuis,
                "TUIs": tuis,
            })

# Create a DataFrame from the collected data
df = pd.DataFrame(data_list)

# %% [markdown]
# Save data as json

# %%
# Define the path to save the JSON output
output_json_path = r"C:\OpenAlex Tagging Enhancement for Biomedical Text\Scripts\BioRel\BioeRel_cTAKES_processed_output.json"

# Save the DataFrame to a JSON file
# df.to_json(output_json_path, orient='records', lines=True)
df.to_json(output_json_path, orient='records', lines=False, indent=4)

print(f"DataFrame has been saved as JSON to {output_json_path}")
# Out:
# DataFrame has been saved as JSON to C:\OpenAlex Tagging Enhancement for Biomedical Text\Scripts\BioRel\BioeRel_cTAKES_processed_output.json

# %%
df.head(2)
# Out:
#                               File_name  \
# 0  000ccbf4-2c18-4d38-932b-a7521855ba75
# 1  0017c8ae-2d34-4a3b-9935-57eb71cb5e3e
#
#                                               Tokens  \
# 0  [proliferative, cells, malignant cells, cells,...
# 1  [sperms, seminiferous tubules, tissue, follicl...
#
#                                                 CUIs  \
# 0  [C0334094, C0007634, C0334227, C0007634, C1261...
# 1  [C0037868, C0036630, C0040300, C0018120, C0007...
#
#                                    TUIs
# 0  [T046, T025, T025, T025, T191, T116]
# 1        [T025, T023, T024, T023, T025]

# %% [markdown]
# Save data as csv
